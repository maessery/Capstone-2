# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import os
import seaborn as sns
from datetime import datetime
import fnmatch
import sys
import glob

# %%
xl_list = glob.glob('./Stats\**\*.xlsx', recursive = True)

player_files =[]

for file in xl_list:
    player_files.append(file)

files_xlsx= [f for f in xl_list if f[-4:] == "xlsx"]
files_xlsx
# Out:
# ['./Stats\\2007-08\\2007-08goalies.xlsx',
#  './Stats\\2007-08\\2007-08skaters.xlsx',
#  './Stats\\2007-08\\2007-08skaters_adv.xlsx',
#  './Stats\\2008-09\\2008-09goalies.xlsx',
#  './Stats\\2008-09\\2008-09goalies_shootout.xlsx',
#  './Stats\\2008-09\\2008-09skaters.xlsx',
#  './Stats\\2008-09\\2008-09skaters_adv.xlsx',
#  './Stats\\2008-09\\2008-09skaters_shootout.xlsx',
#  './Stats\\2009-10\\2009-10goalies.xlsx',
#  './Stats\\2009-10\\2009-10goalies_shootout.xlsx',
#  './Stats\\2009-10\\2009-10skaters.xlsx',
#  './Stats\\2009-10\\2009-10skaters_adv.xlsx',
#  './Stats\\2009-10\\2009-10skaters_shootout.xlsx',
#  './Stats\\2010-11\\2010-11goalies.xlsx',
#  './Stats\\2010-11\\2010-11goalies_shootout.xlsx',
#  './Stats\\2010-11\\2010-11skaters.xlsx',
#  './Stats\\2010-11\\2010-11skaters_adv.xlsx',
#  './Stats\\2010-11\\2010-11skaters_shootout.xlsx',
#  './Stats\\2011-12\\2011-12goalies.xlsx',
#  './Stats\\2011-12\\2011-12goalies_shootout.xlsx',
#  './Stats\\2011-12\\2011-12skaters.xlsx',
#  './Stats\\2011-12\\2011-12skaters_adv.xlsx',
#  './Stats\\2011-12\\2011-12skaters_shootout.xlsx',
#  './Stats\\2012-13\\2012-13goalies.xlsx',
#  './Stats\\2012-13\\2012-13goalies_shootout.xlsx',
#  './Stats\\2012-13\\2012-13skaters.xlsx',
#  './Stats\\2012-13\\2012-13skaters_adv.xlsx',
#  './Stats\\2012-13\\2012-13skaters_shootout.xlsx',
#  './Stats\\2013-14\\2013-14goalies.xlsx',
#  './Stats\\2013-14\\2013-14goalies_shootout.xlsx',
#  './Stats\\2013-14\\2013-14skaters.xlsx',
#  './Stats\\2013-14\\2013-14skaters_adv.xlsx',
#  './Stats\\2013-14\\2013-14skaters_shootout.xlsx',
#  './Stats\\2014-15\\2014-15goalies.xlsx',
#  './Stats\\2014-15\\2014-15goalies_shootout.xlsx',
#  './Stats\\2014-15\\2014-15skaters.xlsx',
#  './Stats\\2014-15\\2014-15skaters_adv.xlsx',
#  './Stats\\2014-15\\2014-15skaters_misc.xlsx',
#  './Stats\\2015-16\\2015-16goalies.xlsx',
#  './Stats\\2015-16\\2015-16goalies_shootout.xlsx',
#  './Stats\\2015-16\\2015-16skaters.xlsx',
#  './Stats\\2015-16\\2015-16skaters_adv.xlsx',
#  './Stats\\2015-16\\2015-16skaters_misc.xlsx',
#  './Stats\\2016-17\\2016-17goalies.xlsx',
#  './Stats\\2016-17\\2016-17goalies_shootout.xlsx',
#  './Stats\\2016-17\\2016-17skaters.xlsx',
#  './Stats\\2016-17\\2016-17skaters_adv.xlsx',
#  './Stats\\2016-17\\2016-17skaters_misc.xlsx',
#  './Stats\\2017-18\\2017-18goalie.xlsx',
#  './Stats\\2017-18\\2017-18goalie_shootout.xlsx',
#  './Stats\\2017-18\\2017-18skaters.xlsx',
#  './Stats\\2017-18\\2017-18skaters_misc.xlsx',
#  './Stats\\2017-18\\2017-18skaters_shootout.xlsx',
#  './Stats\\2018-19\\2018-19goalie.xlsx',
#  './Stats\\2018-19\\2018-19goalie_shootout.xlsx',
#  './Stats\\2018-19\\2018-19skaters.xlsx',
#  './Stats\\2018-19\\2018-19skaters_adv.xlsx',
#  './Stats\\2018-19\\2018-19skaters_misc.xlsx',
#  './Stats\\2018-19\\2018-19skaters_shootout.xlsx',
#  './Stats\\2019-20\\2019-20goalies.xlsx',
#  './Stats\\2019-20\\2019-20goalie_shootout.xlsx',
#  './Stats\\2019-20\\2019-20skaters.xlsx',
#  './Stats\\2019-20\\2019-20skaters_adv.xlsx',
#  './Stats\\2019-20\\2019-20skaters_misc.xlsx',
#  './Stats\\2019-20\\2019-20skaters_shootout.xlsx',
#  './Stats\\2020-21\\2020-21goalies.xlsx',
#  './Stats\\2020-21\\2020-21goalie_shootout.xlsx',
#  './Stats\\2020-21\\2020-21skaters.xlsx',
#  './Stats\\2020-21\\2020-21skaters_adv.xlsx',
#  './Stats\\2020-21\\2020-21skaters_shootout.xlsx',
#  './Stats\\2020-21\\2020-21skater_misc.xlsx']

# %%
player_files
# Out:
# ['./Stats\\2007-08\\2007-08goalies.xlsx',
#  './Stats\\2007-08\\2007-08skaters.xlsx',
#  './Stats\\2007-08\\2007-08skaters_adv.xlsx',
#  './Stats\\2008-09\\2008-09goalies.xlsx',
#  './Stats\\2008-09\\2008-09goalies_shootout.xlsx',
#  './Stats\\2008-09\\2008-09skaters.xlsx',
#  './Stats\\2008-09\\2008-09skaters_adv.xlsx',
#  './Stats\\2008-09\\2008-09skaters_shootout.xlsx',
#  './Stats\\2009-10\\2009-10goalies.xlsx',
#  './Stats\\2009-10\\2009-10goalies_shootout.xlsx',
#  './Stats\\2009-10\\2009-10skaters.xlsx',
#  './Stats\\2009-10\\2009-10skaters_adv.xlsx',
#  './Stats\\2009-10\\2009-10skaters_shootout.xlsx',
#  './Stats\\2010-11\\2010-11goalies.xlsx',
#  './Stats\\2010-11\\2010-11goalies_shootout.xlsx',
#  './Stats\\2010-11\\2010-11skaters.xlsx',
#  './Stats\\2010-11\\2010-11skaters_adv.xlsx',
#  './Stats\\2010-11\\2010-11skaters_shootout.xlsx',
#  './Stats\\2011-12\\2011-12goalies.xlsx',
#  './Stats\\2011-12\\2011-12goalies_shootout.xlsx',
#  './Stats\\2011-12\\2011-12skaters.xlsx',
#  './Stats\\2011-12\\2011-12skaters_adv.xlsx',
#  './Stats\\2011-12\\2011-12skaters_shootout.xlsx',
#  './Stats\\2012-13\\2012-13goalies.xlsx',
#  './Stats\\2012-13\\2012-13goalies_shootout.xlsx',
#  './Stats\\2012-13\\2012-13skaters.xlsx',
#  './Stats\\2012-13\\2012-13skaters_adv.xlsx',
#  './Stats\\2012-13\\2012-13skaters_shootout.xlsx',
#  './Stats\\2013-14\\2013-14goalies.xlsx',
#  './Stats\\2013-14\\2013-14goalies_shootout.xlsx',
#  './Stats\\2013-14\\2013-14skaters.xlsx',
#  './Stats\\2013-14\\2013-14skaters_adv.xlsx',
#  './Stats\\2013-14\\2013-14skaters_shootout.xlsx',
#  './Stats\\2014-15\\2014-15goalies.xlsx',
#  './Stats\\2014-15\\2014-15goalies_shootout.xlsx',
#  './Stats\\2014-15\\2014-15skaters.xlsx',
#  './Stats\\2014-15\\2014-15skaters_adv.xlsx',
#  './Stats\\2014-15\\2014-15skaters_misc.xlsx',
#  './Stats\\2015-16\\2015-16goalies.xlsx',
#  './Stats\\2015-16\\2015-16goalies_shootout.xlsx',
#  './Stats\\2015-16\\2015-16skaters.xlsx',
#  './Stats\\2015-16\\2015-16skaters_adv.xlsx',
#  './Stats\\2015-16\\2015-16skaters_misc.xlsx',
#  './Stats\\2016-17\\2016-17goalies.xlsx',
#  './Stats\\2016-17\\2016-17goalies_shootout.xlsx',
#  './Stats\\2016-17\\2016-17skaters.xlsx',
#  './Stats\\2016-17\\2016-17skaters_adv.xlsx',
#  './Stats\\2016-17\\2016-17skaters_misc.xlsx',
#  './Stats\\2017-18\\2017-18goalie.xlsx',
#  './Stats\\2017-18\\2017-18goalie_shootout.xlsx',
#  './Stats\\2017-18\\2017-18skaters.xlsx',
#  './Stats\\2017-18\\2017-18skaters_misc.xlsx',
#  './Stats\\2017-18\\2017-18skaters_shootout.xlsx',
#  './Stats\\2018-19\\2018-19goalie.xlsx',
#  './Stats\\2018-19\\2018-19goalie_shootout.xlsx',
#  './Stats\\2018-19\\2018-19skaters.xlsx',
#  './Stats\\2018-19\\2018-19skaters_adv.xlsx',
#  './Stats\\2018-19\\2018-19skaters_misc.xlsx',
#  './Stats\\2018-19\\2018-19skaters_shootout.xlsx',
#  './Stats\\2019-20\\2019-20goalies.xlsx',
#  './Stats\\2019-20\\2019-20goalie_shootout.xlsx',
#  './Stats\\2019-20\\2019-20skaters.xlsx',
#  './Stats\\2019-20\\2019-20skaters_adv.xlsx',
#  './Stats\\2019-20\\2019-20skaters_misc.xlsx',
#  './Stats\\2019-20\\2019-20skaters_shootout.xlsx',
#  './Stats\\2020-21\\2020-21goalies.xlsx',
#  './Stats\\2020-21\\2020-21goalie_shootout.xlsx',
#  './Stats\\2020-21\\2020-21skaters.xlsx',
#  './Stats\\2020-21\\2020-21skaters_adv.xlsx',
#  './Stats\\2020-21\\2020-21skaters_shootout.xlsx',
#  './Stats\\2020-21\\2020-21skater_misc.xlsx']

# %%
skaters=[]

for file in player_files:
    if file.endswith('skaters.xlsx') or file.endswith('misc.xlsx') or file.endswith('adv.xlsx') or file.endswith('skaters_shootout.xlsx'):
        skaters.append(file)

# %%
skaters
# Out:
# ['./Stats\\2007-08\\2007-08skaters.xlsx',
#  './Stats\\2007-08\\2007-08skaters_adv.xlsx',
#  './Stats\\2008-09\\2008-09skaters.xlsx',
#  './Stats\\2008-09\\2008-09skaters_adv.xlsx',
#  './Stats\\2008-09\\2008-09skaters_shootout.xlsx',
#  './Stats\\2009-10\\2009-10skaters.xlsx',
#  './Stats\\2009-10\\2009-10skaters_adv.xlsx',
#  './Stats\\2009-10\\2009-10skaters_shootout.xlsx',
#  './Stats\\2010-11\\2010-11skaters.xlsx',
#  './Stats\\2010-11\\2010-11skaters_adv.xlsx',
#  './Stats\\2010-11\\2010-11skaters_shootout.xlsx',
#  './Stats\\2011-12\\2011-12skaters.xlsx',
#  './Stats\\2011-12\\2011-12skaters_adv.xlsx',
#  './Stats\\2011-12\\2011-12skaters_shootout.xlsx',
#  './Stats\\2012-13\\2012-13skaters.xlsx',
#  './Stats\\2012-13\\2012-13skaters_adv.xlsx',
#  './Stats\\2012-13\\2012-13skaters_shootout.xlsx',
#  './Stats\\2013-14\\2013-14skaters.xlsx',
#  './Stats\\2013-14\\2013-14skaters_adv.xlsx',
#  './Stats\\2013-14\\2013-14skaters_shootout.xlsx',
#  './Stats\\2014-15\\2014-15skaters.xlsx',
#  './Stats\\2014-15\\2014-15skaters_adv.xlsx',
#  './Stats\\2014-15\\2014-15skaters_misc.xlsx',
#  './Stats\\2015-16\\2015-16skaters.xlsx',
#  './Stats\\2015-16\\2015-16skaters_adv.xlsx',
#  './Stats\\2015-16\\2015-16skaters_misc.xlsx',
#  './Stats\\2016-17\\2016-17skaters.xlsx',
#  './Stats\\2016-17\\2016-17skaters_adv.xlsx',
#  './Stats\\2016-17\\2016-17skaters_misc.xlsx',
#  './Stats\\2017-18\\2017-18skaters.xlsx',
#  './Stats\\2017-18\\2017-18skaters_misc.xlsx',
#  './Stats\\2017-18\\2017-18skaters_shootout.xlsx',
#  './Stats\\2018-19\\2018-19skaters.xlsx',
#  './Stats\\2018-19\\2018-19skaters_adv.xlsx',
#  './Stats\\2018-19\\2018-19skaters_misc.xlsx',
#  './Stats\\2018-19\\2018-19skaters_shootout.xlsx',
#  './Stats\\2019-20\\2019-20skaters.xlsx',
#  './Stats\\2019-20\\2019-20skaters_adv.xlsx',
#  './Stats\\2019-20\\2019-20skaters_misc.xlsx',
#  './Stats\\2019-20\\2019-20skaters_shootout.xlsx',
#  './Stats\\2020-21\\2020-21skaters.xlsx',
#  './Stats\\2020-21\\2020-21skaters_adv.xlsx',
#  './Stats\\2020-21\\2020-21skaters_shootout.xlsx',
#  './Stats\\2020-21\\2020-21skater_misc.xlsx']

# %%
def preclean(file):
    file=file.drop(columns='Unnamed: 0')
    file=file.T
    file=file.set_index(0)
    file=file.T
    return (file)
    
def shootout_cleaner(file):
    file=preclean(file)
    file=file.drop(1, axis=0)
    file=file[['Player','Att.','Made','Miss','Pct.']]
    return (file)

# %% [markdown]
# #                  2008-2009 SEASON PLAYER STATS

# %%
s0809=pd.DataFrame()
s0809= pd.read_excel('./Stats/2008-09/2008-09skaters.xlsx', engine= 'openpyxl')

sa_0809=pd.DataFrame()
sa_0809=pd.read_excel('./Stats/2008-09/2008-09skaters_adv.xlsx', engine='openpyxl')

ss_0809=pd.DataFrame()
ss_0809=pd.read_excel('./Stats/2008-09/2008-09skaters_shootout.xlsx', engine='openpyxl')

# %%
s0809.head()
# Out:
#   Unnamed: 0         Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Scoring  \
# 0         Rk             Player        Age         Tm        Pos      GP
# 1          1  Justin Abdelkader         21        DET         LW       2
# 2          2        Craig Adams         31        TOT         RW      45
# 3          2        Craig Adams         31        CHI         RW      36
# 4          2        Craig Adams         31        PIT         RW       9
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 18 Shot Data  \
# 0          G          A        PTS        +/-  ...          SH         S
# 1          0          0          0          0  ...           0         2
# 2          2          5          7         -3  ...           0        47
# 3          2          4          6         -3  ...           0        38
# 4          0          1          1          0  ...           0         9
#
#   Unnamed: 20 Ice Time Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25  \
# 0          S%      TOI        ATOI         BLK         HIT         FOW
# 1           0       19    09:18:00           0           3           4
# 2         4.3      391    08:41:00          20          67           8
# 3         5.3      314    08:43:00          16          53           6
# 4           0       77    08:34:00           4          14           2
#
#   Unnamed: 26 Unnamed: 27
# 0         FOL         FO%
# 1           3        57.1
# 2          13        38.1
# 3          10        37.5
# 4           3          40
#
# [5 rows x 28 columns]

# %%
s0809= preclean(s0809)

# %%
s0809
# Out:
# 0                Player Age   Tm Pos  GP   G   A PTS  +/- PIM  ... SH    S  \
# 1     Justin Abdelkader  21  DET  LW   2   0   0   0    0   0  ...  0    2
# 2           Craig Adams  31  TOT  RW  45   2   5   7   -3  22  ...  0   47
# 3           Craig Adams  31  CHI  RW  36   2   4   6   -3  22  ...  0   38
# 4           Craig Adams  31  PIT  RW   9   0   1   1    0   0  ...  0    9
# 5      Maxim Afinogenov  29  BUF  RW  48   6  14  20   -7  20  ...  0   93
# ...                 ...  ..  ...  ..  ..  ..  ..  ..  ...  ..  ... ..  ...
# 1070     Marek Zidlicky  31  MIN   D  76  12  30  42  -12  76  ...  0  147
# 1071     Mike Zigomanis  28  PIT   C  22   2   4   6   -2  27  ...  0   23
# 1072         Ilya Zubov  21  OTT   C  10   0   2   2   -1   0  ...  0   11
# 1073      Sergei Zubov*  38  DAL   D  10   0   4   4   -4   0  ...  0   15
# 1074     Dainius Zubrus  30  NJD   C  82  15  25  40    6  69  ...  0  130
#
# 0       S%   TOI                 ATOI BLK HIT  FOW  FOL   FO%
# 1        0    19             09:18:00   0   3    4    3  57.1
# 2      4.3   391             08:41:00  20  67    8   13  38.1
# 3      5.3   314             08:43:00  16  53    6   10  37.5
# 4        0    77             08:34:00   4  14    2    3    40
# 5      6.5   605             12:36:00  11  20    0    3     0
# ...    ...   ...                  ...  ..  ..  ...  ...   ...
# 1070   8.2  1680             22:07:00  95  74    0    0   NaN
# 1071   8.7   251             11:26:00   8  17  158   93  62.9
# 1072     0   103             10:17:00   2  11    0    1     0
# 1073     0   243  1900-01-01 00:18:00   3   6    0    0   NaN
# 1074  11.5  1252             15:16:00  16  98  473  450  51.2
#
# [1074 rows x 27 columns]

# %%
s0809['Season']=2008

# %%
s0809.head()
# Out:
# 0             Player Age   Tm Pos  GP  G   A PTS +/- PIM  ...   S   S%  TOI  \
# 1  Justin Abdelkader  21  DET  LW   2  0   0   0   0   0  ...   2    0   19
# 2        Craig Adams  31  TOT  RW  45  2   5   7  -3  22  ...  47  4.3  391
# 3        Craig Adams  31  CHI  RW  36  2   4   6  -3  22  ...  38  5.3  314
# 4        Craig Adams  31  PIT  RW   9  0   1   1   0   0  ...   9    0   77
# 5   Maxim Afinogenov  29  BUF  RW  48  6  14  20  -7  20  ...  93  6.5  605
#
# 0      ATOI BLK HIT FOW FOL   FO% Season
# 1  09:18:00   0   3   4   3  57.1   2008
# 2  08:41:00  20  67   8  13  38.1   2008
# 3  08:43:00  16  53   6  10  37.5   2008
# 4  08:34:00   4  14   2   3    40   2008
# 5  12:36:00  11  20   0   3     0   2008
#
# [5 rows x 28 columns]

# %%
s0809=s0809.set_index(['Season'])

# %%
s0809
# Out:
# 0                  Player Age   Tm Pos  GP   G   A PTS  +/- PIM  ... SH    S  \
# Season                                                           ...
# 2008    Justin Abdelkader  21  DET  LW   2   0   0   0    0   0  ...  0    2
# 2008          Craig Adams  31  TOT  RW  45   2   5   7   -3  22  ...  0   47
# 2008          Craig Adams  31  CHI  RW  36   2   4   6   -3  22  ...  0   38
# 2008          Craig Adams  31  PIT  RW   9   0   1   1    0   0  ...  0    9
# 2008     Maxim Afinogenov  29  BUF  RW  48   6  14  20   -7  20  ...  0   93
# ...                   ...  ..  ...  ..  ..  ..  ..  ..  ...  ..  ... ..  ...
# 2008       Marek Zidlicky  31  MIN   D  76  12  30  42  -12  76  ...  0  147
# 2008       Mike Zigomanis  28  PIT   C  22   2   4   6   -2  27  ...  0   23
# 2008           Ilya Zubov  21  OTT   C  10   0   2   2   -1   0  ...  0   11
# 2008        Sergei Zubov*  38  DAL   D  10   0   4   4   -4   0  ...  0   15
# 2008       Dainius Zubrus  30  NJD   C  82  15  25  40    6  69  ...  0  130
#
# 0         S%   TOI                 ATOI BLK HIT  FOW  FOL   FO%
# Season
# 2008       0    19             09:18:00   0   3    4    3  57.1
# 2008     4.3   391             08:41:00  20  67    8   13  38.1
# 2008     5.3   314             08:43:00  16  53    6   10  37.5
# 2008       0    77             08:34:00   4  14    2    3    40
# 2008     6.5   605             12:36:00  11  20    0    3     0
# ...      ...   ...                  ...  ..  ..  ...  ...   ...
# 2008     8.2  1680             22:07:00  95  74    0    0   NaN
# 2008     8.7   251             11:26:00   8  17  158   93  62.9
# 2008       0   103             10:17:00   2  11    0    1     0
# 2008       0   243  1900-01-01 00:18:00   3   6    0    0   NaN
# 2008    11.5  1252             15:16:00  16  98  473  450  51.2
#
# [1074 rows x 27 columns]

# %%
s0809.loc[s0809.Tm=='TOT',:]
# Out:
# 0                 Player Age   Tm Pos  GP   G   A PTS  +/-  PIM  ... SH    S  \
# Season                                                           ...
# 2008         Craig Adams  31  TOT  RW  45   2   5   7   -3   22  ...  0   47
# 2008        Nik Antropov  28  TOT  RW  81  28  31  59  -14   30  ...  1  224
# 2008          Sean Avery  28  TOT  LW  41   8  14  22    6  111  ...  0   99
# 2008         Steve Begin  30  TOT  LW  62   7   5  12   -6   42  ...  0   90
# 2008          Wade Belak  32  TOT  RW  53   0   2   2   -1   79  ...  0   19
# ...                  ...  ..  ...  ..  ..  ..  ..  ..  ...  ...  ... ..  ...
# 2008        Ryan Whitney  25  TOT   D  48   2  21  23  -14   28  ...  0   71
# 2008      Jason Williams  28  TOT  RW  80  19  28  47   -4   24  ...  0  153
# 2008     Justin Williams  27  TOT  RW  44   4  10  14   -8   17  ...  0  108
# 2008         Clay Wilson  25  TOT   D   7   0   1   1   -3    0  ...  0   13
# 2008    James Wisniewski  24  TOT   D  48   3  21  24    9   30  ...  0   89
#
# 0         S%   TOI      ATOI BLK  HIT  FOW  FOL   FO%
# Season
# 2008     4.3   391  08:41:00  20   67    8   13  38.1
# 2008    12.5  1392  17:11:00  37  112   80  117  40.6
# 2008     8.1   646  15:45:00   7   89    9    9    50
# 2008     7.8   665  10:43:00  38  185   65   68  48.9
# 2008       0   278  05:15:00   6   57    0    0   NaN
# ...      ...   ...       ...  ..  ...  ...  ...   ...
# 2008     2.8  1146  23:52:00  69   37    0    0   NaN
# 2008    12.4  1269  15:51:00  32   45  284  334    46
# 2008     3.7   699  15:53:00   9   40    7   15  31.8
# 2008       0    79  11:17:00   1    6    0    0   NaN
# 2008     3.4   953  19:51:00  60   90    0    0   NaN
#
# [72 rows x 27 columns]

# %%
a=s0809[s0809.duplicated(subset='Player')]
a
# Out:
# 0                 Player  Age   Tm  Pos  GP   G   A  PTS  +/-  PIM  ...  SH  \
# Season                                                              ...
# 2008         Craig Adams   31  CHI   RW  36   2   4    6   -3   22  ...   0
# 2008         Craig Adams   31  PIT   RW   9   0   1    1    0    0  ...   0
# 2008        Nik Antropov   28  TOR   RW  63  21  25   46  -13   24  ...   1
# 2008        Nik Antropov   28  NYR   RW  18   7   6   13   -1    6  ...   0
# 2008          Sean Avery   28  DAL   LW  23   3   7   10    2   77  ...   0
# ...                  ...  ...  ...  ...  ..  ..  ..  ...  ...  ...  ...  ..
# 2008         Clay Wilson   25  CBJ    D   5   0   1    1   -2    0  ...   0
# 2008         Clay Wilson   25  ATL    D   2   0   0    0   -1    0  ...   0
# 2008    James Wisniewski   24  CHI    D  31   2  11   13    6   14  ...   0
# 2008    James Wisniewski   24  ANA    D  17   1  10   11    3   16  ...   0
# 2008              Player  Age   Tm  Pos  GP   G   A  PTS  +/-  PIM  ...  SH
#
# 0         S    S%   TOI      ATOI  BLK  HIT  FOW  FOL   FO%
# Season
# 2008     38   5.3   314  08:43:00   16   53    6   10  37.5
# 2008      9     0    77  08:34:00    4   14    2    3    40
# 2008    171  12.3  1085  17:13:00   31   80   80  113  41.5
# 2008     53  13.2   308  17:05:00    6   32    0    4     0
# 2008     49   6.1   345  14:59:00    3   44    5    7  41.7
# ...     ...   ...   ...       ...  ...  ...  ...  ...   ...
# 2008      9     0    47  09:26:00    1    4    0    0   NaN
# 2008      4     0    32  15:55:00    0    2    0    0   NaN
# 2008     70   2.9   597  19:15:00   31   51    0    0   NaN
# 2008     19   5.3   356  20:57:00   29   39    0    0   NaN
# 2008      S    S%   TOI      ATOI  BLK  HIT  FOW  FOL   FO%
#
# [189 rows x 27 columns]

# %%
df.loc[(slice(None), 't'), :]

# %%
dan= s0809.loc[(slice(None),'Daniel Alfredsson'),:]
dan
# Out:
# 0                        Age   Tm Pos  GP   G   A PTS +/- PIM   PS  ... SH  \
# Season Player                                                       ...
# 2008   Daniel Alfredsson  36  OTT  RW  79  24  50  74   7  24  8.1  ...  3
#
# 0                           S    S%   TOI      ATOI BLK HIT FOW FOL   FO%
# Season Player
# 2008   Daniel Alfredsson  204  11.8  1649  20:53:00  33  57   4  13  23.5
#
# [1 rows x 26 columns]

# %%
dan.T
# Out:
# Season              2008
# Player Daniel Alfredsson
# 0
# Age                   36
# Tm                   OTT
# Pos                   RW
# GP                    79
# G                     24
# A                     50
# PTS                   74
# +/-                    7
# PIM                   24
# PS                   8.1
# EV                    15
# PP                     8
# SH                     1
# GW                     3
# EV                    27
# PP                    20
# SH                     3
# S                    204
# S%                  11.8
# TOI                 1649
# ATOI            20:53:00
# BLK                   33
# HIT                   57
# FOW                    4
# FOL                   13
# FO%                 23.5

# %%
sa_0809= preclean(sa_0809)

# %%
sa_0809
# Out:
# 0               Player Age   Tm Pos  GP    CF    CA   CF% CF% rel   FF  ...  \
# 1    Justin Abdelkader  21  DET  LW   2    22     9    71    14.6   16  ...
# 2          Craig Adams  31  TOT  RW  45   306   274  52.8    -3.2  238  ...
# 3     Maxim Afinogenov  29  BUF  RW  48   501   454  52.5     2.4  363  ...
# 4       Andrew Alberts  27  PHI   D  79   921   998    48    -1.8  697  ...
# 5    Daniel Alfredsson  36  OTT  RW  79  1122  1000  52.9     3.3  835  ...
# ..                 ...  ..  ...  ..  ..   ...   ...   ...     ...  ...  ...
# 925     Marek Zidlicky  31  MIN   D  76  1188  1103  51.9     4.6  894  ...
# 926     Mike Zigomanis  28  PIT   C  22   146   167  46.6    -2.2  106  ...
# 927         Ilya Zubov  21  OTT   C  10    74    69  51.7     1.7   51  ...
# 928      Sergei Zubov*  38  DAL   D  10   155   156  49.8    -3.8  124  ...
# 929     Dainius Zubrus  30  NJD   C  82  1046   851  55.1       2  780  ...
#
# 0   oiSV%    PDO  oZS%  dZS%               TOI/60   TOI(EV)  TK  GV SAtt.  \
# 1     100    100  66.7  33.3             09:18:00  09:18:00   0   1     7
# 2    93.1   96.9  56.5  43.5             08:41:00  07:43:00   7   3    81
# 3      90     97  52.3  47.7             12:36:00  10:08:00  15  36   172
# 4    91.5  100.7  49.8  50.2             15:47:00  13:09:00  27  59   122
# 5    90.1   99.9  52.5  47.5             20:47:00  14:17:00  72  56   350
# ..    ...    ...   ...   ...                  ...       ...  ..  ..   ...
# 925  91.4     98  56.4  43.6             22:06:00  17:07:00  12  47   319
# 926    89   98.9  35.3  64.7             11:26:00  08:01:00   6   2    38
# 927  95.1   97.9  48.8  51.2             10:17:00  08:24:00   6   4    19
# 928    88   98.3  53.8  46.3  1900-01-01 00:18:00  17:44:00   4  11    39
# 929  91.7  100.4  51.6  48.4             15:16:00  13:04:00  19  25   207
#
# 0   Thru%
# 1    28.6
# 2      58
# 3    54.1
# 4    37.7
# 5    58.3
# ..    ...
# 925  46.1
# 926  60.5
# 927  57.9
# 928  38.5
# 929  62.8
#
# [929 rows x 24 columns]

# %%
sa_0809['Season']=2008
sa_0809
# Out:
# 0               Player Age   Tm Pos  GP    CF    CA   CF% CF% rel   FF  ...  \
# 1    Justin Abdelkader  21  DET  LW   2    22     9    71    14.6   16  ...
# 2          Craig Adams  31  TOT  RW  45   306   274  52.8    -3.2  238  ...
# 3     Maxim Afinogenov  29  BUF  RW  48   501   454  52.5     2.4  363  ...
# 4       Andrew Alberts  27  PHI   D  79   921   998    48    -1.8  697  ...
# 5    Daniel Alfredsson  36  OTT  RW  79  1122  1000  52.9     3.3  835  ...
# ..                 ...  ..  ...  ..  ..   ...   ...   ...     ...  ...  ...
# 925     Marek Zidlicky  31  MIN   D  76  1188  1103  51.9     4.6  894  ...
# 926     Mike Zigomanis  28  PIT   C  22   146   167  46.6    -2.2  106  ...
# 927         Ilya Zubov  21  OTT   C  10    74    69  51.7     1.7   51  ...
# 928      Sergei Zubov*  38  DAL   D  10   155   156  49.8    -3.8  124  ...
# 929     Dainius Zubrus  30  NJD   C  82  1046   851  55.1       2  780  ...
#
# 0      PDO  oZS%  dZS%               TOI/60   TOI(EV)  TK  GV SAtt. Thru%  \
# 1      100  66.7  33.3             09:18:00  09:18:00   0   1     7  28.6
# 2     96.9  56.5  43.5             08:41:00  07:43:00   7   3    81    58
# 3       97  52.3  47.7             12:36:00  10:08:00  15  36   172  54.1
# 4    100.7  49.8  50.2             15:47:00  13:09:00  27  59   122  37.7
# 5     99.9  52.5  47.5             20:47:00  14:17:00  72  56   350  58.3
# ..     ...   ...   ...                  ...       ...  ..  ..   ...   ...
# 925     98  56.4  43.6             22:06:00  17:07:00  12  47   319  46.1
# 926   98.9  35.3  64.7             11:26:00  08:01:00   6   2    38  60.5
# 927   97.9  48.8  51.2             10:17:00  08:24:00   6   4    19  57.9
# 928   98.3  53.8  46.3  1900-01-01 00:18:00  17:44:00   4  11    39  38.5
# 929  100.4  51.6  48.4             15:16:00  13:04:00  19  25   207  62.8
#
# 0   Season
# 1     2008
# 2     2008
# 3     2008
# 4     2008
# 5     2008
# ..     ...
# 925   2008
# 926   2008
# 927   2008
# 928   2008
# 929   2008
#
# [929 rows x 25 columns]

# %%
sa_0809=sa_0809.reset_index()
sa_0809=sa_0809.set_index(['Season','Player'])

# %%
sa_0809
# Out:
# 0                        Age   Tm Pos  GP    CF    CA   CF% CF% rel   FF   FA  \
# Season Player
# 2008   Justin Abdelkader  21  DET  LW   2    22     9    71    14.6   16    8
#        Craig Adams        31  TOT  RW  45   306   274  52.8    -3.2  238  198
#        Maxim Afinogenov   29  BUF  RW  48   501   454  52.5     2.4  363  340
#        Andrew Alberts     27  PHI   D  79   921   998    48    -1.8  697  723
#        Daniel Alfredsson  36  OTT  RW  79  1122  1000  52.9     3.3  835  745
# ...                       ..  ...  ..  ..   ...   ...   ...     ...  ...  ...
#        Marek Zidlicky     31  MIN   D  76  1188  1103  51.9     4.6  894  841
#        Mike Zigomanis     28  PIT   C  22   146   167  46.6    -2.2  106  128
#        Ilya Zubov         21  OTT   C  10    74    69  51.7     1.7   51   55
#        Sergei Zubov*      38  DAL   D  10   155   156  49.8    -3.8  124  127
#        Dainius Zubrus     30  NJD   C  82  1046   851  55.1       2  780  665
#
# 0                         ... oiSV%    PDO  oZS%  dZS%               TOI/60  \
# Season Player             ...
# 2008   Justin Abdelkader  ...   100    100  66.7  33.3             09:18:00
#        Craig Adams        ...  93.1   96.9  56.5  43.5             08:41:00
#        Maxim Afinogenov   ...    90     97  52.3  47.7             12:36:00
#        Andrew Alberts     ...  91.5  100.7  49.8  50.2             15:47:00
#        Daniel Alfredsson  ...  90.1   99.9  52.5  47.5             20:47:00
# ...                       ...   ...    ...   ...   ...                  ...
#        Marek Zidlicky     ...  91.4     98  56.4  43.6             22:06:00
#        Mike Zigomanis     ...    89   98.9  35.3  64.7             11:26:00
#        Ilya Zubov         ...  95.1   97.9  48.8  51.2             10:17:00
#        Sergei Zubov*      ...    88   98.3  53.8  46.3  1900-01-01 00:18:00
#        Dainius Zubrus     ...  91.7  100.4  51.6  48.4             15:16:00
#
# 0                          TOI(EV)  TK  GV SAtt. Thru%
# Season Player
# 2008   Justin Abdelkader  09:18:00   0   1     7  28.6
#        Craig Adams        07:43:00   7   3    81    58
#        Maxim Afinogenov   10:08:00  15  36   172  54.1
#        Andrew Alberts     13:09:00  27  59   122  37.7
#        Daniel Alfredsson  14:17:00  72  56   350  58.3
# ...                            ...  ..  ..   ...   ...
#        Marek Zidlicky     17:07:00  12  47   319  46.1
#        Mike Zigomanis     08:01:00   6   2    38  60.5
#        Ilya Zubov         08:24:00   6   4    19  57.9
#        Sergei Zubov*      17:44:00   4  11    39  38.5
#        Dainius Zubrus     13:04:00  19  25   207  62.8
#
# [929 rows x 23 columns]

# %%
sa_0809= sa_0809.drop(columns='index')

# %%
sa_0809= sa_0809.drop(columns='Rk')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-2ef71a556b62> in <module>
# ----> 1 sa_0809= sa_0809.drop(columns='Rk')
#
# c:\users\squatch\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# c:\users\squatch\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# c:\users\squatch\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3921                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3922             else:
# -> 3923                 new_axis = axis.drop(labels, errors=errors)
#    3924             result = self.reindex(**{axis_name: new_axis})
#    3925
#
# c:\users\squatch\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5285         if mask.any():
#    5286             if errors != "ignore":
# -> 5287                 raise KeyError(f"{labels[mask]} not found in axis")
#    5288             indexer = indexer[~mask]
#    5289         return self.delete(indexer)
#
# KeyError: "['Rk'] not found in axis"

# %%
sa_0809
# Out:
# 0                        Age   Tm Pos  GP    CF    CA   CF% CF% rel   FF   FA  \
# Season Player
# 2008   Justin Abdelkader  21  DET  LW   2    22     9    71    14.6   16    8
#        Craig Adams        31  TOT  RW  45   306   274  52.8    -3.2  238  198
#        Maxim Afinogenov   29  BUF  RW  48   501   454  52.5     2.4  363  340
#        Andrew Alberts     27  PHI   D  79   921   998    48    -1.8  697  723
#        Daniel Alfredsson  36  OTT  RW  79  1122  1000  52.9     3.3  835  745
# ...                       ..  ...  ..  ..   ...   ...   ...     ...  ...  ...
#        Marek Zidlicky     31  MIN   D  76  1188  1103  51.9     4.6  894  841
#        Mike Zigomanis     28  PIT   C  22   146   167  46.6    -2.2  106  128
#        Ilya Zubov         21  OTT   C  10    74    69  51.7     1.7   51   55
#        Sergei Zubov*      38  DAL   D  10   155   156  49.8    -3.8  124  127
#        Dainius Zubrus     30  NJD   C  82  1046   851  55.1       2  780  665
#
# 0                         ... oiSV%    PDO  oZS%  dZS%               TOI/60  \
# Season Player             ...
# 2008   Justin Abdelkader  ...   100    100  66.7  33.3             09:18:00
#        Craig Adams        ...  93.1   96.9  56.5  43.5             08:41:00
#        Maxim Afinogenov   ...    90     97  52.3  47.7             12:36:00
#        Andrew Alberts     ...  91.5  100.7  49.8  50.2             15:47:00
#        Daniel Alfredsson  ...  90.1   99.9  52.5  47.5             20:47:00
# ...                       ...   ...    ...   ...   ...                  ...
#        Marek Zidlicky     ...  91.4     98  56.4  43.6             22:06:00
#        Mike Zigomanis     ...    89   98.9  35.3  64.7             11:26:00
#        Ilya Zubov         ...  95.1   97.9  48.8  51.2             10:17:00
#        Sergei Zubov*      ...    88   98.3  53.8  46.3  1900-01-01 00:18:00
#        Dainius Zubrus     ...  91.7  100.4  51.6  48.4             15:16:00
#
# 0                          TOI(EV)  TK  GV SAtt. Thru%
# Season Player
# 2008   Justin Abdelkader  09:18:00   0   1     7  28.6
#        Craig Adams        07:43:00   7   3    81    58
#        Maxim Afinogenov   10:08:00  15  36   172  54.1
#        Andrew Alberts     13:09:00  27  59   122  37.7
#        Daniel Alfredsson  14:17:00  72  56   350  58.3
# ...                            ...  ..  ..   ...   ...
#        Marek Zidlicky     17:07:00  12  47   319  46.1
#        Mike Zigomanis     08:01:00   6   2    38  60.5
#        Ilya Zubov         08:24:00   6   4    19  57.9
#        Sergei Zubov*      17:44:00   4  11    39  38.5
#        Dainius Zubrus     13:04:00  19  25   207  62.8
#
# [929 rows x 23 columns]

# %%
sa_0809.columns
# Out:
# Index(['Age', 'Tm', 'Pos', 'GP', 'CF', 'CA', 'CF%', 'CF% rel', 'FF', 'FA',
#        'FF%', 'FF% rel', 'oiSH%', 'oiSV%', 'PDO', 'oZS%', 'dZS%', 'TOI/60',
#        'TOI(EV)', 'TK', 'GV', 'SAtt.', 'Thru%'],
#       dtype='object', name=0)

# %%
dan2= sa_0809.loc[(slice(None),'Daniel Alfredsson'),:]
dan2.T
# Out:
# Season               2008
# Player  Daniel Alfredsson
# 0
# Age                    36
# Tm                    OTT
# Pos                    RW
# GP                     79
# CF                   1122
# CA                   1000
# CF%                  52.9
# CF% rel               3.3
# FF                    835
# FA                    745
# FF%                  52.8
# FF% rel               2.4
# oiSH%                 9.8
# oiSV%                90.1
# PDO                  99.9
# oZS%                 52.5
# dZS%                 47.5
# TOI/60           20:47:00
# TOI(EV)          14:17:00
# TK                     72
# GV                     56
# SAtt.                 350
# Thru%                58.3

# %%
ss_0809.head()
# Out:
#              Player   Tm Att. Made Miss Pct.
# 0   Jeff Tambellini  NYI    2    2    0  100
# 1     Jeff Hamilton  TOR    2    2    0  100
# 2         Adam Hall  TBL    1    1    0  100
# 3  Brendan Shanahan  NJD    1    1    0  100
# 4      Darcy Tucker  COL    1    1    0  100

# %%
ss_0809=ss_0809.reset_index()

ss_0809['Season']=2008

ss_0809=ss_0809.set_index(['Season','Player'])

ss_0809= ss_0809.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})

# %%
ss_0809
# Out:
#                          index   Tm SOT_Att SOT_Scored SOT_Saved SOT_Pct
# Season Player
# 2008   Jeff Tambellini       0  NYI       2          2         0     100
#        Jeff Hamilton         1  TOR       2          2         0     100
#        Adam Hall             2  TBL       1          1         0     100
#        Brendan Shanahan      3  NJD       1          1         0     100
#        Darcy Tucker          4  COL       1          1         0     100
# ...                        ...  ...     ...        ...       ...     ...
#        Paul Kariya         267  STL       1          0         1       0
#        Krys Kolanos        268  MIN       1          0         1       0
#        Sami Salo           269  VAN       1          0         1       0
#        Kamil Kreps         270  FLA       1          0         1       0
#        Mark Recchi         271  TBL       1          0         1       0
#
# [272 rows x 6 columns]

# %%
skater1= s0809.merge(sa_0809, how='inner', on=['Season','Player'])
skater1
# Out:
# 0                        Age_x Tm_x Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Season Player                                                             ...
# 2008   Justin Abdelkader    21  DET    LW    2   0   0   0    0   0    0  ...
#        Craig Adams          31  TOT    RW   45   2   5   7   -3  22  0.1  ...
#        Craig Adams          31  CHI    RW   36   2   4   6   -3  22  0.1  ...
#        Craig Adams          31  PIT    RW    9   0   1   1    0   0    0  ...
#        Maxim Afinogenov     29  BUF    RW   48   6  14  20   -7  20  1.4  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
#        Marek Zidlicky       31  MIN     D   76  12  30  42  -12  76  7.8  ...
#        Mike Zigomanis       28  PIT     C   22   2   4   6   -2  27  0.3  ...
#        Ilya Zubov           21  OTT     C   10   0   2   2   -1   0    0  ...
#        Sergei Zubov*        38  DAL     D   10   0   4   4   -4   0  0.3  ...
#        Dainius Zubrus       30  NJD     C   82  15  25  40    6  69  3.7  ...
#
# 0                        oiSV%    PDO  oZS%  dZS%               TOI/60  \
# Season Player
# 2008   Justin Abdelkader   100    100  66.7  33.3             09:18:00
#        Craig Adams        93.1   96.9  56.5  43.5             08:41:00
#        Craig Adams        93.1   96.9  56.5  43.5             08:41:00
#        Craig Adams        93.1   96.9  56.5  43.5             08:41:00
#        Maxim Afinogenov     90     97  52.3  47.7             12:36:00
# ...                        ...    ...   ...   ...                  ...
#        Marek Zidlicky     91.4     98  56.4  43.6             22:06:00
#        Mike Zigomanis       89   98.9  35.3  64.7             11:26:00
#        Ilya Zubov         95.1   97.9  48.8  51.2             10:17:00
#        Sergei Zubov*        88   98.3  53.8  46.3  1900-01-01 00:18:00
#        Dainius Zubrus     91.7  100.4  51.6  48.4             15:16:00
#
# 0                          TOI(EV)  TK  GV SAtt. Thru%
# Season Player
# 2008   Justin Abdelkader  09:18:00   0   1     7  28.6
#        Craig Adams        07:43:00   7   3    81    58
#        Craig Adams        07:43:00   7   3    81    58
#        Craig Adams        07:43:00   7   3    81    58
#        Maxim Afinogenov   10:08:00  15  36   172  54.1
# ...                            ...  ..  ..   ...   ...
#        Marek Zidlicky     17:07:00  12  47   319  46.1
#        Mike Zigomanis     08:01:00   6   2    38  60.5
#        Ilya Zubov         08:24:00   6   4    19  57.9
#        Sergei Zubov*      17:44:00   4  11    39  38.5
#        Dainius Zubrus     13:04:00  19  25   207  62.8
#
# [2968 rows x 49 columns]

# %%
skater2= skater1.merge(ss_0809, how='left', on=['Season','Player'])
skater2
# Out:
#                          Age_x Tm_x Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Season Player                                                             ...
# 2008   Justin Abdelkader    21  DET    LW    2   0   0   0    0   0    0  ...
#        Craig Adams          31  TOT    RW   45   2   5   7   -3  22  0.1  ...
#        Craig Adams          31  CHI    RW   36   2   4   6   -3  22  0.1  ...
#        Craig Adams          31  PIT    RW    9   0   1   1    0   0    0  ...
#        Maxim Afinogenov     29  BUF    RW   48   6  14  20   -7  20  1.4  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
#        Marek Zidlicky       31  MIN     D   76  12  30  42  -12  76  7.8  ...
#        Mike Zigomanis       28  PIT     C   22   2   4   6   -2  27  0.3  ...
#        Ilya Zubov           21  OTT     C   10   0   2   2   -1   0    0  ...
#        Sergei Zubov*        38  DAL     D   10   0   4   4   -4   0  0.3  ...
#        Dainius Zubrus       30  NJD     C   82  15  25  40    6  69  3.7  ...
#
#                           TK  GV SAtt. Thru% index   Tm SOT_Att SOT_Scored  \
# Season Player
# 2008   Justin Abdelkader   0   1     7  28.6   NaN  NaN     NaN        NaN
#        Craig Adams         7   3    81    58   NaN  NaN     NaN        NaN
#        Craig Adams         7   3    81    58   NaN  NaN     NaN        NaN
#        Craig Adams         7   3    81    58   NaN  NaN     NaN        NaN
#        Maxim Afinogenov   15  36   172  54.1   NaN  NaN     NaN        NaN
# ...                       ..  ..   ...   ...   ...  ...     ...        ...
#        Marek Zidlicky     12  47   319  46.1  31.0  MIN       5          3
#        Mike Zigomanis      6   2    38  60.5   NaN  NaN     NaN        NaN
#        Ilya Zubov          6   4    19  57.9   NaN  NaN     NaN        NaN
#        Sergei Zubov*       4  11    39  38.5   NaN  NaN     NaN        NaN
#        Dainius Zubrus     19  25   207  62.8   NaN  NaN     NaN        NaN
#
#                          SOT_Saved SOT_Pct
# Season Player
# 2008   Justin Abdelkader       NaN     NaN
#        Craig Adams             NaN     NaN
#        Craig Adams             NaN     NaN
#        Craig Adams             NaN     NaN
#        Maxim Afinogenov        NaN     NaN
# ...                            ...     ...
#        Marek Zidlicky            2      60
#        Mike Zigomanis          NaN     NaN
#        Ilya Zubov              NaN     NaN
#        Sergei Zubov*           NaN     NaN
#        Dainius Zubrus          NaN     NaN
#
# [24264 rows x 55 columns]

# %%
skaters0809= skater2

# %%
#trythis= s0809.merge(sa_0809, how='inner', on=['Season','Player']).merge(ss_0809, how='left', on=['Season','Player'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-08f651ec2735> in <module>
# ----> 1 trythis= s0809.merge(sa_0809, how='inner', on=['Season','Player']).merge(ss_0809, how='left', on=['Season','Player'])
#
# NameError: name 's0809' is not defined

# %%
skaters0809.columns
# Out:
# Index(['Age_x', 'Tm_x', 'Pos_x', 'GP_x', 'G', 'A', 'PTS', '+/-', 'PIM', 'PS',
#        'EV', 'PP', 'SH', 'GW', 'EV', 'PP', 'SH', 'S', 'S%', 'TOI', 'ATOI',
#        'BLK', 'HIT', 'FOW', 'FOL', 'FO%', 'Age_y', 'Tm_y', 'Pos_y', 'GP_y',
#        'CF', 'CA', 'CF%', 'CF% rel', 'FF', 'FA', 'FF%', 'FF% rel', 'oiSH%',
#        'oiSV%', 'PDO', 'oZS%', 'dZS%', 'TOI/60', 'TOI(EV)', 'TK', 'GV',
#        'SAtt.', 'Thru%', 'index', 'Tm', 'SOT_Att', 'SOT_Scored', 'SOT_Saved',
#        'SOT_Pct'],
#       dtype='object')

# %%
skaters0809= skaters0809.drop(columns='Tm')

# %%
random = skaters0809.index.get_level_values('Player') != 'Player'

# %%
skaters0809[random]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-cafd10f15832> in <module>
# ----> 1 skaters0809[random]
#
# c:\users\squatch\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2895         # Do we have a (boolean) 1d indexer?
#    2896         if com.is_bool_indexer(key):
# -> 2897             return self._getitem_bool_array(key)
#    2898
#    2899         # We are left with two options: a single key, and a collection of keys,
#
# c:\users\squatch\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    2942         elif len(key) != len(self.index):
#    2943             raise ValueError(
# -> 2944                 f"Item wrong length {len(key)} instead of {len(self.index)}."
#    2945             )
#    2946
#
# ValueError: Item wrong length 24264 instead of 1032.

# %%
skaters0809
# Out:
#                          Age_x Tm_x Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Season Player                                                             ...
# 2008   Justin Abdelkader    21  DET    LW    2   0   0   0    0   0    0  ...
#        Craig Adams          31  TOT    RW   45   2   5   7   -3  22  0.1  ...
#        Craig Adams          31  CHI    RW   36   2   4   6   -3  22  0.1  ...
#        Craig Adams          31  PIT    RW    9   0   1   1    0   0    0  ...
#        Maxim Afinogenov     29  BUF    RW   48   6  14  20   -7  20  1.4  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
#        Marek Zidlicky       31  MIN     D   76  12  30  42  -12  76  7.8  ...
#        Mike Zigomanis       28  PIT     C   22   2   4   6   -2  27  0.3  ...
#        Ilya Zubov           21  OTT     C   10   0   2   2   -1   0    0  ...
#        Sergei Zubov*        38  DAL     D   10   0   4   4   -4   0  0.3  ...
#        Dainius Zubrus       30  NJD     C   82  15  25  40    6  69  3.7  ...
#
#                           TK  GV SAtt. Thru% index   Tm SOT_Att SOT_Scored  \
# Season Player
# 2008   Justin Abdelkader   0   1     7  28.6   NaN  NaN     NaN        NaN
#        Craig Adams         7   3    81    58   NaN  NaN     NaN        NaN
#        Craig Adams         7   3    81    58   NaN  NaN     NaN        NaN
#        Craig Adams         7   3    81    58   NaN  NaN     NaN        NaN
#        Maxim Afinogenov   15  36   172  54.1   NaN  NaN     NaN        NaN
# ...                       ..  ..   ...   ...   ...  ...     ...        ...
#        Marek Zidlicky     12  47   319  46.1  31.0  MIN       5          3
#        Mike Zigomanis      6   2    38  60.5   NaN  NaN     NaN        NaN
#        Ilya Zubov          6   4    19  57.9   NaN  NaN     NaN        NaN
#        Sergei Zubov*       4  11    39  38.5   NaN  NaN     NaN        NaN
#        Dainius Zubrus     19  25   207  62.8   NaN  NaN     NaN        NaN
#
#                          SOT_Saved SOT_Pct
# Season Player
# 2008   Justin Abdelkader       NaN     NaN
#        Craig Adams             NaN     NaN
#        Craig Adams             NaN     NaN
#        Craig Adams             NaN     NaN
#        Maxim Afinogenov        NaN     NaN
# ...                            ...     ...
#        Marek Zidlicky            2      60
#        Mike Zigomanis          NaN     NaN
#        Ilya Zubov              NaN     NaN
#        Sergei Zubov*           NaN     NaN
#        Dainius Zubrus          NaN     NaN
#
# [1032 rows x 55 columns]

# %%
skaters0809.columns
# Out:
# Index(['Age_x', 'Tm_x', 'Pos_x', 'GP_x', 'G', 'A', 'PTS', '+/-', 'PIM', 'PS',
#        'EV', 'PP', 'SH', 'GW', 'EV', 'PP', 'SH', 'S', 'S%', 'TOI', 'ATOI',
#        'BLK', 'HIT', 'FOW', 'FOL', 'FO%', 'Age_y', 'Tm_y', 'Pos_y', 'GP_y',
#        'CF', 'CA', 'CF%', 'CF% rel', 'FF', 'FA', 'FF%', 'FF% rel', 'oiSH%',
#        'oiSV%', 'PDO', 'oZS%', 'dZS%', 'TOI/60', 'TOI(EV)', 'TK', 'GV',
#        'SAtt.', 'Thru%', 'index', 'Tm', 'SOT_Att', 'SOT_Scored', 'SOT_Saved',
#        'SOT_Pct'],
#       dtype='object')

# %%
skaters0809.drop(columns=['Age_y','Tm_y','Pos_y','GP_y'])
# Out:
#                          Age_x Tm_x Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Season Player                                                             ...
# 2008   Justin Abdelkader    21  DET    LW    2   0   0   0    0   0    0  ...
#        Craig Adams          31  TOT    RW   45   2   5   7   -3  22  0.1  ...
#        Craig Adams          31  CHI    RW   36   2   4   6   -3  22  0.1  ...
#        Craig Adams          31  PIT    RW    9   0   1   1    0   0    0  ...
#        Maxim Afinogenov     29  BUF    RW   48   6  14  20   -7  20  1.4  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
#        Marek Zidlicky       31  MIN     D   76  12  30  42  -12  76  7.8  ...
#        Mike Zigomanis       28  PIT     C   22   2   4   6   -2  27  0.3  ...
#        Ilya Zubov           21  OTT     C   10   0   2   2   -1   0    0  ...
#        Sergei Zubov*        38  DAL     D   10   0   4   4   -4   0  0.3  ...
#        Dainius Zubrus       30  NJD     C   82  15  25  40    6  69  3.7  ...
#
#                           TK  GV SAtt. Thru% index   Tm SOT_Att SOT_Scored  \
# Season Player
# 2008   Justin Abdelkader   0   1     7  28.6   NaN  NaN     NaN        NaN
#        Craig Adams         7   3    81    58   NaN  NaN     NaN        NaN
#        Craig Adams         7   3    81    58   NaN  NaN     NaN        NaN
#        Craig Adams         7   3    81    58   NaN  NaN     NaN        NaN
#        Maxim Afinogenov   15  36   172  54.1   NaN  NaN     NaN        NaN
# ...                       ..  ..   ...   ...   ...  ...     ...        ...
#        Marek Zidlicky     12  47   319  46.1  31.0  MIN       5          3
#        Mike Zigomanis      6   2    38  60.5   NaN  NaN     NaN        NaN
#        Ilya Zubov          6   4    19  57.9   NaN  NaN     NaN        NaN
#        Sergei Zubov*       4  11    39  38.5   NaN  NaN     NaN        NaN
#        Dainius Zubrus     19  25   207  62.8   NaN  NaN     NaN        NaN
#
#                          SOT_Saved SOT_Pct
# Season Player
# 2008   Justin Abdelkader       NaN     NaN
#        Craig Adams             NaN     NaN
#        Craig Adams             NaN     NaN
#        Craig Adams             NaN     NaN
#        Maxim Afinogenov        NaN     NaN
# ...                            ...     ...
#        Marek Zidlicky            2      60
#        Mike Zigomanis          NaN     NaN
#        Ilya Zubov              NaN     NaN
#        Sergei Zubov*           NaN     NaN
#        Dainius Zubrus          NaN     NaN
#
# [1032 rows x 51 columns]

# %%
skaters0809= skaters0809.drop(columns=['index','Tm'])
skaters0809
# Out:
#                          Age_x Tm_x Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Season Player                                                             ...
# 2008   Justin Abdelkader    21  DET    LW    2   0   0   0    0   0    0  ...
#        Craig Adams          31  TOT    RW   45   2   5   7   -3  22  0.1  ...
#        Craig Adams          31  CHI    RW   36   2   4   6   -3  22  0.1  ...
#        Craig Adams          31  PIT    RW    9   0   1   1    0   0    0  ...
#        Maxim Afinogenov     29  BUF    RW   48   6  14  20   -7  20  1.4  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
#        Marek Zidlicky       31  MIN     D   76  12  30  42  -12  76  7.8  ...
#        Mike Zigomanis       28  PIT     C   22   2   4   6   -2  27  0.3  ...
#        Ilya Zubov           21  OTT     C   10   0   2   2   -1   0    0  ...
#        Sergei Zubov*        38  DAL     D   10   0   4   4   -4   0  0.3  ...
#        Dainius Zubrus       30  NJD     C   82  15  25  40    6  69  3.7  ...
#
#                                        TOI/60   TOI(EV)  TK  GV SAtt. Thru%  \
# Season Player
# 2008   Justin Abdelkader             09:18:00  09:18:00   0   1     7  28.6
#        Craig Adams                   08:41:00  07:43:00   7   3    81    58
#        Craig Adams                   08:41:00  07:43:00   7   3    81    58
#        Craig Adams                   08:41:00  07:43:00   7   3    81    58
#        Maxim Afinogenov              12:36:00  10:08:00  15  36   172  54.1
# ...                                       ...       ...  ..  ..   ...   ...
#        Marek Zidlicky                22:06:00  17:07:00  12  47   319  46.1
#        Mike Zigomanis                11:26:00  08:01:00   6   2    38  60.5
#        Ilya Zubov                    10:17:00  08:24:00   6   4    19  57.9
#        Sergei Zubov*      1900-01-01 00:18:00  17:44:00   4  11    39  38.5
#        Dainius Zubrus                15:16:00  13:04:00  19  25   207  62.8
#
#                          SOT_Att SOT_Scored SOT_Saved SOT_Pct
# Season Player
# 2008   Justin Abdelkader     NaN        NaN       NaN     NaN
#        Craig Adams           NaN        NaN       NaN     NaN
#        Craig Adams           NaN        NaN       NaN     NaN
#        Craig Adams           NaN        NaN       NaN     NaN
#        Maxim Afinogenov      NaN        NaN       NaN     NaN
# ...                          ...        ...       ...     ...
#        Marek Zidlicky          5          3         2      60
#        Mike Zigomanis        NaN        NaN       NaN     NaN
#        Ilya Zubov            NaN        NaN       NaN     NaN
#        Sergei Zubov*         NaN        NaN       NaN     NaN
#        Dainius Zubrus        NaN        NaN       NaN     NaN
#
# [1032 rows x 53 columns]

# %%
replace_nulls= skaters0809[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters0809[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters0809
# Out:
#                          Age_x Tm_x Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Season Player                                                             ...
# 2008   Justin Abdelkader    21  DET    LW    2   0   0   0    0   0    0  ...
#        Craig Adams          31  TOT    RW   45   2   5   7   -3  22  0.1  ...
#        Craig Adams          31  CHI    RW   36   2   4   6   -3  22  0.1  ...
#        Craig Adams          31  PIT    RW    9   0   1   1    0   0    0  ...
#        Maxim Afinogenov     29  BUF    RW   48   6  14  20   -7  20  1.4  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
#        Marek Zidlicky       31  MIN     D   76  12  30  42  -12  76  7.8  ...
#        Mike Zigomanis       28  PIT     C   22   2   4   6   -2  27  0.3  ...
#        Ilya Zubov           21  OTT     C   10   0   2   2   -1   0    0  ...
#        Sergei Zubov*        38  DAL     D   10   0   4   4   -4   0  0.3  ...
#        Dainius Zubrus       30  NJD     C   82  15  25  40    6  69  3.7  ...
#
#                                        TOI/60   TOI(EV)  TK  GV SAtt. Thru%  \
# Season Player
# 2008   Justin Abdelkader             09:18:00  09:18:00   0   1     7  28.6
#        Craig Adams                   08:41:00  07:43:00   7   3    81    58
#        Craig Adams                   08:41:00  07:43:00   7   3    81    58
#        Craig Adams                   08:41:00  07:43:00   7   3    81    58
#        Maxim Afinogenov              12:36:00  10:08:00  15  36   172  54.1
# ...                                       ...       ...  ..  ..   ...   ...
#        Marek Zidlicky                22:06:00  17:07:00  12  47   319  46.1
#        Mike Zigomanis                11:26:00  08:01:00   6   2    38  60.5
#        Ilya Zubov                    10:17:00  08:24:00   6   4    19  57.9
#        Sergei Zubov*      1900-01-01 00:18:00  17:44:00   4  11    39  38.5
#        Dainius Zubrus                15:16:00  13:04:00  19  25   207  62.8
#
#                          SOT_Att SOT_Scored SOT_Saved SOT_Pct
# Season Player
# 2008   Justin Abdelkader       0          0         0     0.0
#        Craig Adams             0          0         0     0.0
#        Craig Adams             0          0         0     0.0
#        Craig Adams             0          0         0     0.0
#        Maxim Afinogenov        0          0         0     0.0
# ...                          ...        ...       ...     ...
#        Marek Zidlicky          5          3         2    60.0
#        Mike Zigomanis          0          0         0     0.0
#        Ilya Zubov              0          0         0     0.0
#        Sergei Zubov*           0          0         0     0.0
#        Dainius Zubrus          0          0         0     0.0
#
# [1032 rows x 53 columns]

# %%
###USE THIS ONE###

#load
s0809=pd.DataFrame()
s0809= pd.read_excel('./Stats/2008-09/2008-09skaters.xlsx', engine= 'openpyxl')

sa_0809=pd.DataFrame()
sa_0809=pd.read_excel('./Stats/2008-09/2008-09skaters_adv.xlsx', engine='openpyxl')

ss_0809=pd.DataFrame()
ss_0809=pd.read_excel('./Stats/2008-09/2008-09skaters_shootout.xlsx', engine='openpyxl')


#regular stats
s0809= preclean(s0809)
s0809['Season']=2008
s0809= s0809.set_index(['Season','Player'])


#advanced

sa_0809 = preclean(sa_0809)


sa_0809['Season']=2008
sa_0809= sa_0809.set_index(['Season','Player'])
sa_0809= sa_0809.drop(columns='Tm')



#shootout

ss_0809=ss_0809.reset_index()

ss_0809['Season']=2008

ss_0809=ss_0809.set_index(['Season','Player'])

ss_0809= ss_0809.drop(columns=['Tm','index'])

ss_0809= ss_0809.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})


#merge

skaters0809= s0809.merge(sa_0809, how='inner', on=['Season','Player']).merge(ss_0809, how='left', on=['Season','Player'])


#clean some more

skaters0809= skaters0809[skaters0809.index.get_level_values('Player') != 'Player']


replace_nulls= skaters0809[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters0809[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters0809= skaters0809.drop(columns=['Age_y','Pos_y','GP_y'])

skaters0809
# Out:
#                          Age_x   Tm Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Season Player                                                             ...
# 2008   Justin Abdelkader    21  DET    LW    2   0   0   0    0   0    0  ...
#        Craig Adams          31  TOT    RW   45   2   5   7   -3  22  0.1  ...
#        Craig Adams          31  CHI    RW   36   2   4   6   -3  22  0.1  ...
#        Craig Adams          31  PIT    RW    9   0   1   1    0   0    0  ...
#        Maxim Afinogenov     29  BUF    RW   48   6  14  20   -7  20  1.4  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
#        Marek Zidlicky       31  MIN     D   76  12  30  42  -12  76  7.8  ...
#        Mike Zigomanis       28  PIT     C   22   2   4   6   -2  27  0.3  ...
#        Ilya Zubov           21  OTT     C   10   0   2   2   -1   0    0  ...
#        Sergei Zubov*        38  DAL     D   10   0   4   4   -4   0  0.3  ...
#        Dainius Zubrus       30  NJD     C   82  15  25  40    6  69  3.7  ...
#
#                                        TOI/60   TOI(EV)  TK  GV SAtt. Thru%  \
# Season Player
# 2008   Justin Abdelkader             09:18:00  09:18:00   0   1     7  28.6
#        Craig Adams                   08:41:00  07:43:00   7   3    81    58
#        Craig Adams                   08:41:00  07:43:00   7   3    81    58
#        Craig Adams                   08:41:00  07:43:00   7   3    81    58
#        Maxim Afinogenov              12:36:00  10:08:00  15  36   172  54.1
# ...                                       ...       ...  ..  ..   ...   ...
#        Marek Zidlicky                22:06:00  17:07:00  12  47   319  46.1
#        Mike Zigomanis                11:26:00  08:01:00   6   2    38  60.5
#        Ilya Zubov                    10:17:00  08:24:00   6   4    19  57.9
#        Sergei Zubov*      1900-01-01 00:18:00  17:44:00   4  11    39  38.5
#        Dainius Zubrus                15:16:00  13:04:00  19  25   207  62.8
#
#                          SOT_Att SOT_Scored SOT_Saved SOT_Pct
# Season Player
# 2008   Justin Abdelkader       0          0         0     0.0
#        Craig Adams             0          0         0     0.0
#        Craig Adams             0          0         0     0.0
#        Craig Adams             0          0         0     0.0
#        Maxim Afinogenov        0          0         0     0.0
# ...                          ...        ...       ...     ...
#        Marek Zidlicky          5          3         2    60.0
#        Mike Zigomanis          0          0         0     0.0
#        Ilya Zubov              0          0         0     0.0
#        Sergei Zubov*           0          0         0     0.0
#        Dainius Zubrus          0          0         0     0.0
#
# [1032 rows x 49 columns]

# %%
#load
s0809=pd.DataFrame()
s0809= pd.read_excel('./Stats/2008-09/2008-09skaters.xlsx', engine= 'openpyxl')

sa_0809=pd.DataFrame()
sa_0809=pd.read_excel('./Stats/2008-09/2008-09skaters_adv.xlsx', engine='openpyxl')

ss_0809=pd.DataFrame()
ss_0809=pd.read_excel('./Stats/2008-09/2008-09skaters_shootout.xlsx', engine='openpyxl')


#regular stats
s0809= preclean(s0809)
s0809['Season']=2008
s0809= s0809.set_index(['Player','Season'])


#advanced

sa_0809 = preclean(sa_0809)


sa_0809['Season']=2008
sa_0809= sa_0809.set_index(['Player','Season'])
sa_0809= sa_0809.drop(columns='Tm')



#shootout

ss_0809=ss_0809.reset_index()

ss_0809['Season']=2008

ss_0809=ss_0809.set_index(['Player','Season'])

ss_0809= ss_0809.drop(columns=['Tm','index'])

ss_0809= ss_0809.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})


#merge and clean

skaters0809= s0809.merge(sa_0809, how='inner', on=['Player','Season']).merge(ss_0809, how='left', on=['Player','Season'])


skaters0809= skaters0809[skaters0809.index.get_level_values('Player') != 'Player']


replace_nulls= skaters0809[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters0809[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters0809= skaters0809.drop(columns=['Age_y','Pos_y','GP_y'])

skaters0809
# Out:
#                          Age_x   Tm Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Player            Season                                                  ...
# Justin Abdelkader 2008      21  DET    LW    2   0   0   0    0   0    0  ...
# Craig Adams       2008      31  TOT    RW   45   2   5   7   -3  22  0.1  ...
#                   2008      31  CHI    RW   36   2   4   6   -3  22  0.1  ...
#                   2008      31  PIT    RW    9   0   1   1    0   0    0  ...
# Maxim Afinogenov  2008      29  BUF    RW   48   6  14  20   -7  20  1.4  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
# Marek Zidlicky    2008      31  MIN     D   76  12  30  42  -12  76  7.8  ...
# Mike Zigomanis    2008      28  PIT     C   22   2   4   6   -2  27  0.3  ...
# Ilya Zubov        2008      21  OTT     C   10   0   2   2   -1   0    0  ...
# Sergei Zubov*     2008      38  DAL     D   10   0   4   4   -4   0  0.3  ...
# Dainius Zubrus    2008      30  NJD     C   82  15  25  40    6  69  3.7  ...
#
#                                        TOI/60   TOI(EV)  TK  GV SAtt. Thru%  \
# Player            Season
# Justin Abdelkader 2008               09:18:00  09:18:00   0   1     7  28.6
# Craig Adams       2008               08:41:00  07:43:00   7   3    81    58
#                   2008               08:41:00  07:43:00   7   3    81    58
#                   2008               08:41:00  07:43:00   7   3    81    58
# Maxim Afinogenov  2008               12:36:00  10:08:00  15  36   172  54.1
# ...                                       ...       ...  ..  ..   ...   ...
# Marek Zidlicky    2008               22:06:00  17:07:00  12  47   319  46.1
# Mike Zigomanis    2008               11:26:00  08:01:00   6   2    38  60.5
# Ilya Zubov        2008               10:17:00  08:24:00   6   4    19  57.9
# Sergei Zubov*     2008    1900-01-01 00:18:00  17:44:00   4  11    39  38.5
# Dainius Zubrus    2008               15:16:00  13:04:00  19  25   207  62.8
#
#                          SOT_Att SOT_Scored SOT_Saved SOT_Pct
# Player            Season
# Justin Abdelkader 2008         0          0         0     0.0
# Craig Adams       2008         0          0         0     0.0
#                   2008         0          0         0     0.0
#                   2008         0          0         0     0.0
# Maxim Afinogenov  2008         0          0         0     0.0
# ...                          ...        ...       ...     ...
# Marek Zidlicky    2008         5          3         2    60.0
# Mike Zigomanis    2008         0          0         0     0.0
# Ilya Zubov        2008         0          0         0     0.0
# Sergei Zubov*     2008         0          0         0     0.0
# Dainius Zubrus    2008         0          0         0     0.0
#
# [1032 rows x 49 columns]

# %%
skaters0809.to_csv('./Clean/skaters2008.csv')

# %% [markdown]
# #                    2009-2010 PLAYER STATISTICS

# %%
s0910=pd.DataFrame()
s0910= pd.read_excel('./Stats/2009-10/2009-10skaters.xlsx', engine= 'openpyxl')

sa_0910=pd.DataFrame()
sa_0910=pd.read_excel('./Stats/2009-10/2009-10skaters_adv.xlsx', engine='openpyxl')

ss_0910=pd.DataFrame()
ss_0910=pd.read_excel('./Stats/2009-10/2009-10skaters_shootout.xlsx', engine='openpyxl')

# %%
s0910.head()
# Out:
#   Unnamed: 0         Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Scoring  \
# 0         Rk             Player        Age         Tm        Pos      GP
# 1          1  Justin Abdelkader         22        DET         LW      50
# 2          2        Craig Adams         32        PIT         RW      82
# 3          3   Maxim Afinogenov         30        ATL         RW      82
# 4          4     Andrew Alberts         28        TOT          D      76
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 18 Shot Data  \
# 0          G          A        PTS        +/-  ...          SH         S
# 1          3          3          6        -11  ...           0        79
# 2          0         10         10         -5  ...           0        84
# 3         24         37         61        -17  ...           0       181
# 4          3          9         12          6  ...           0        50
#
#   Unnamed: 20 Ice Time Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25  \
# 0          S%      TOI        ATOI         BLK         HIT         FOW
# 1         3.8      530    10:35:00          20         152         148
# 2           0      910    11:06:00          58         193         243
# 3        13.3     1426    17:24:00          21          32           1
# 4           6     1169    15:23:00          88         216           0
#
#   Unnamed: 26 Unnamed: 27
# 0         FOL         FO%
# 1         170        46.5
# 2         311        43.9
# 3           2        33.3
# 4           1           0
#
# [5 rows x 28 columns]

# %%
#regular stats
s0910= preclean(s0910)
s0910['Season']=2009
s0910= s0910.set_index(['Season','Player'])
s0910.head()
# Out:
# 0                        Age   Tm Pos  GP   G   A PTS  +/- PIM   PS  ... SH  \
# Season Player                                                        ...
# 2009   Justin Abdelkader  22  DET  LW  50   3   3   6  -11  35 -0.3  ...  0
#        Craig Adams        32  PIT  RW  82   0  10  10   -5  72 -0.8  ...  0
#        Maxim Afinogenov   30  ATL  RW  82  24  37  61  -17  46  5.7  ...  0
#        Andrew Alberts     28  TOT   D  76   3   9  12    6  87  3.1  ...  0
#        Andrew Alberts     28  CAR   D  62   2   8  10    7  74  2.7  ...  0
#
# 0                           S    S%   TOI      ATOI BLK  HIT  FOW  FOL   FO%
# Season Player
# 2009   Justin Abdelkader   79   3.8   530  10:35:00  20  152  148  170  46.5
#        Craig Adams         84     0   910  11:06:00  58  193  243  311  43.9
#        Maxim Afinogenov   181  13.3  1426  17:24:00  21   32    1    2  33.3
#        Andrew Alberts      50     6  1169  15:23:00  88  216    0    1     0
#        Andrew Alberts      38   5.3   935  15:04:00  67  172    0    0   NaN
#
# [5 rows x 26 columns]

# %%
#advanced stats
sa_0910 = preclean(sa_0910)
sa_0910.head()

sa_0910['Season']=2009
sa_0910= sa_0910.set_index(['Season','Player'])
sa_0910.head()
# Out:
# 0                        Age   Tm Pos  GP    CF    CA   CF% CF% rel   FF   FA  \
# Season Player
# 2009   Justin Abdelkader  22  DET  LW  50   409   376  52.1    -2.2  303  280
#        Craig Adams        32  PIT  RW  82   511   604  45.8    -9.2  376  421
#        Maxim Afinogenov   30  ATL  RW  82  1076  1107  49.3    -0.7  785  860
#        Andrew Alberts     28  TOT   D  76   933   885  51.3    -0.7  680  665
#        Daniel Alfredsson  37  OTT  RW  70   850   878  49.2    -3.9  621  646
#
# 0                         ... oiSV%    PDO  oZS%  dZS%    TOI/60   TOI(EV)  \
# Season Player             ...
# 2009   Justin Abdelkader  ...    90   94.3  66.3  33.7  10:35:00  09:36:00
#        Craig Adams        ...    92   99.2  42.4  57.6  10:57:00  08:11:00
#        Maxim Afinogenov   ...  89.1     99  49.2  50.8  17:23:00  14:12:00
#        Andrew Alberts     ...  90.5  100.9  46.8  53.2  15:13:00  13:10:00
#        Daniel Alfredsson  ...  91.3  101.4  55.2  44.8  19:23:00  13:43:00
#
# 0                         TK  GV SAtt. Thru%
# Season Player
# 2009   Justin Abdelkader   7   7   141    56
#        Craig Adams        22  12   144  56.3
#        Maxim Afinogenov   65  63   321  56.4
#        Andrew Alberts     19  39   129  37.2
#        Daniel Alfredsson  76  42   308  52.9
#
# [5 rows x 23 columns]

# %%
#shootout stats
ss_0910=ss_0910.reset_index()

ss_0910['Season']=2009

ss_0910=ss_0910.set_index(['Season','Player'])

ss_0910= ss_0910.drop(columns=['Tm','index'])

ss_0910= ss_0910.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})

ss_0910.head()
# Out:
#                          SOT_Att SOT_Scored SOT_Saved SOT_Pct
# Season Player
# 2009   Mike Santorelli         3          3         0     100
#        P.A. Parenteau          3          3         0     100
#        Pascal Dupuis           1          1         0     100
#        Lubomir Visnovsky       1          1         0     100
#        Chris Clark             1          1         0     100

# %%
#merge

skaters0910= s0910.merge(sa_0910, how='inner', on=['Season','Player']).merge(ss_0910, how='left', on=['Season','Player'])

#clean again
skaters0910= skaters0910[skaters0910.index.get_level_values('Player') != 'Player']

skaters0910
# Out:
#                          Age_x Tm_x Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Season Player                                                             ...
# 2009   Justin Abdelkader    22  DET    LW   50   3   3   6  -11  35 -0.3  ...
#        Craig Adams          32  PIT    RW   82   0  10  10   -5  72 -0.8  ...
#        Maxim Afinogenov     30  ATL    RW   82  24  37  61  -17  46  5.7  ...
#        Andrew Alberts       28  TOT     D   76   3   9  12    6  87  3.1  ...
#        Andrew Alberts       28  CAR     D   62   2   8  10    7  74  2.7  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
#        Greg Zanon           29  MIN     D   81   2  13  15  -10  36  3.2  ...
#        Henrik Zetterberg    29  DET    LW   74  23  47  70   12  26  8.2  ...
#        Vladimir Zharkov     22  NJD    RW   40   0  10  10    2   8  0.5  ...
#        Marek Zidlicky       32  MIN     D   78   6  37  43  -16  67  6.3  ...
#        Dainius Zubrus       31  NJD    RW   51  10  17  27    4  28  2.9  ...
#
#                                        TOI/60   TOI(EV)  TK  GV SAtt. Thru%  \
# Season Player
# 2009   Justin Abdelkader             10:35:00  09:36:00   7   7   141    56
#        Craig Adams                   10:57:00  08:11:00  22  12   144  56.3
#        Maxim Afinogenov              17:23:00  14:12:00  65  63   321  56.4
#        Andrew Alberts                15:13:00  13:10:00  19  39   129  37.2
#        Andrew Alberts                15:13:00  13:10:00  19  39   129  37.2
# ...                                       ...       ...  ..  ..   ...   ...
#        Greg Zanon                    22:22:00  18:45:00  25  39   146  40.4
#        Henrik Zetterberg             19:45:00  15:22:00  51  46   515  58.3
#        Vladimir Zharkov              11:26:00  10:05:00   9  14   100    54
#        Marek Zidlicky     1900-01-01 00:09:00  17:36:00  32  52   250  46.4
#        Dainius Zubrus                16:29:00  13:45:00  18  21   131  65.6
#
#                          SOT_Att SOT_Scored SOT_Saved SOT_Pct
# Season Player
# 2009   Justin Abdelkader     NaN        NaN       NaN     NaN
#        Craig Adams           NaN        NaN       NaN     NaN
#        Maxim Afinogenov        3          0         3       0
#        Andrew Alberts        NaN        NaN       NaN     NaN
#        Andrew Alberts        NaN        NaN       NaN     NaN
# ...                          ...        ...       ...     ...
#        Greg Zanon            NaN        NaN       NaN     NaN
#        Henrik Zetterberg      11          2         9    18.2
#        Vladimir Zharkov      NaN        NaN       NaN     NaN
#        Marek Zidlicky          7          2         5    28.6
#        Dainius Zubrus        NaN        NaN       NaN     NaN
#
# [1044 rows x 53 columns]

# %%
#one more clean for nulls
replace_nulls= skaters0910[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters0910[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters0910
# Out:
#                          Age_x Tm_x Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Season Player                                                             ...
# 2009   Justin Abdelkader    22  DET    LW   50   3   3   6  -11  35 -0.3  ...
#        Craig Adams          32  PIT    RW   82   0  10  10   -5  72 -0.8  ...
#        Maxim Afinogenov     30  ATL    RW   82  24  37  61  -17  46  5.7  ...
#        Andrew Alberts       28  TOT     D   76   3   9  12    6  87  3.1  ...
#        Andrew Alberts       28  CAR     D   62   2   8  10    7  74  2.7  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
#        Greg Zanon           29  MIN     D   81   2  13  15  -10  36  3.2  ...
#        Henrik Zetterberg    29  DET    LW   74  23  47  70   12  26  8.2  ...
#        Vladimir Zharkov     22  NJD    RW   40   0  10  10    2   8  0.5  ...
#        Marek Zidlicky       32  MIN     D   78   6  37  43  -16  67  6.3  ...
#        Dainius Zubrus       31  NJD    RW   51  10  17  27    4  28  2.9  ...
#
#                                        TOI/60   TOI(EV)  TK  GV SAtt. Thru%  \
# Season Player
# 2009   Justin Abdelkader             10:35:00  09:36:00   7   7   141    56
#        Craig Adams                   10:57:00  08:11:00  22  12   144  56.3
#        Maxim Afinogenov              17:23:00  14:12:00  65  63   321  56.4
#        Andrew Alberts                15:13:00  13:10:00  19  39   129  37.2
#        Andrew Alberts                15:13:00  13:10:00  19  39   129  37.2
# ...                                       ...       ...  ..  ..   ...   ...
#        Greg Zanon                    22:22:00  18:45:00  25  39   146  40.4
#        Henrik Zetterberg             19:45:00  15:22:00  51  46   515  58.3
#        Vladimir Zharkov              11:26:00  10:05:00   9  14   100    54
#        Marek Zidlicky     1900-01-01 00:09:00  17:36:00  32  52   250  46.4
#        Dainius Zubrus                16:29:00  13:45:00  18  21   131  65.6
#
#                          SOT_Att SOT_Scored SOT_Saved SOT_Pct
# Season Player
# 2009   Justin Abdelkader       0          0         0     0.0
#        Craig Adams             0          0         0     0.0
#        Maxim Afinogenov        3          0         3     0.0
#        Andrew Alberts          0          0         0     0.0
#        Andrew Alberts          0          0         0     0.0
# ...                          ...        ...       ...     ...
#        Greg Zanon              0          0         0     0.0
#        Henrik Zetterberg      11          2         9    18.2
#        Vladimir Zharkov        0          0         0     0.0
#        Marek Zidlicky          7          2         5    28.6
#        Dainius Zubrus          0          0         0     0.0
#
# [1044 rows x 53 columns]

# %%
#load
s0910=pd.DataFrame()
s0910= pd.read_excel('./Stats/2009-10/2009-10skaters.xlsx', engine= 'openpyxl')

sa_0910=pd.DataFrame()
sa_0910=pd.read_excel('./Stats/2009-10/2009-10skaters_adv.xlsx', engine='openpyxl')

ss_0910=pd.DataFrame()
ss_0910=pd.read_excel('./Stats/2009-10/2009-10skaters_shootout.xlsx', engine='openpyxl')


#regular stats
s0910= preclean(s0910)
s0910['Season']=2009
s0910= s0910.set_index(['Season','Player'])


#advanced

sa_0910 = preclean(sa_0910)


sa_0910['Season']=2009
sa_0910= sa_0910.set_index(['Season','Player'])
sa_0910= sa_0910.drop(columns='Tm')



#shootout

ss_0910=ss_0910.reset_index()

ss_0910['Season']=2009

ss_0910=ss_0910.set_index(['Season','Player'])

ss_0910= ss_0910.drop(columns=['Tm','index'])

ss_0910= ss_0910.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})


#merge

skaters0910= s0910.merge(sa_0910, how='inner', on=['Season','Player']).merge(ss_0910, how='left', on=['Season','Player'])


#clean some more

skaters0910= skaters0910[skaters0910.index.get_level_values('Player') != 'Player']


replace_nulls= skaters0910[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters0910[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters0910= skaters0910.drop(columns=['Age_y','Pos_y','GP_y'])

skaters0910
# Out:
#                          Age_x   Tm Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Season Player                                                             ...
# 2009   Justin Abdelkader    22  DET    LW   50   3   3   6  -11  35 -0.3  ...
#        Craig Adams          32  PIT    RW   82   0  10  10   -5  72 -0.8  ...
#        Maxim Afinogenov     30  ATL    RW   82  24  37  61  -17  46  5.7  ...
#        Andrew Alberts       28  TOT     D   76   3   9  12    6  87  3.1  ...
#        Andrew Alberts       28  CAR     D   62   2   8  10    7  74  2.7  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
#        Greg Zanon           29  MIN     D   81   2  13  15  -10  36  3.2  ...
#        Henrik Zetterberg    29  DET    LW   74  23  47  70   12  26  8.2  ...
#        Vladimir Zharkov     22  NJD    RW   40   0  10  10    2   8  0.5  ...
#        Marek Zidlicky       32  MIN     D   78   6  37  43  -16  67  6.3  ...
#        Dainius Zubrus       31  NJD    RW   51  10  17  27    4  28  2.9  ...
#
#                                        TOI/60   TOI(EV)  TK  GV SAtt. Thru%  \
# Season Player
# 2009   Justin Abdelkader             10:35:00  09:36:00   7   7   141    56
#        Craig Adams                   10:57:00  08:11:00  22  12   144  56.3
#        Maxim Afinogenov              17:23:00  14:12:00  65  63   321  56.4
#        Andrew Alberts                15:13:00  13:10:00  19  39   129  37.2
#        Andrew Alberts                15:13:00  13:10:00  19  39   129  37.2
# ...                                       ...       ...  ..  ..   ...   ...
#        Greg Zanon                    22:22:00  18:45:00  25  39   146  40.4
#        Henrik Zetterberg             19:45:00  15:22:00  51  46   515  58.3
#        Vladimir Zharkov              11:26:00  10:05:00   9  14   100    54
#        Marek Zidlicky     1900-01-01 00:09:00  17:36:00  32  52   250  46.4
#        Dainius Zubrus                16:29:00  13:45:00  18  21   131  65.6
#
#                          SOT_Att SOT_Scored SOT_Saved SOT_Pct
# Season Player
# 2009   Justin Abdelkader       0          0         0     0.0
#        Craig Adams             0          0         0     0.0
#        Maxim Afinogenov        3          0         3     0.0
#        Andrew Alberts          0          0         0     0.0
#        Andrew Alberts          0          0         0     0.0
# ...                          ...        ...       ...     ...
#        Greg Zanon              0          0         0     0.0
#        Henrik Zetterberg      11          2         9    18.2
#        Vladimir Zharkov        0          0         0     0.0
#        Marek Zidlicky          7          2         5    28.6
#        Dainius Zubrus          0          0         0     0.0
#
# [1044 rows x 49 columns]

# %%
#load
s0910=pd.DataFrame()
s0910= pd.read_excel('./Stats/2009-10/2009-10skaters.xlsx', engine= 'openpyxl')

sa_0910=pd.DataFrame()
sa_0910=pd.read_excel('./Stats/2009-10/2009-10skaters_adv.xlsx', engine='openpyxl')

ss_0910=pd.DataFrame()
ss_0910=pd.read_excel('./Stats/2009-10/2009-10skaters_shootout.xlsx', engine='openpyxl')


#regular stats
s0910= preclean(s0910)
s0910['Season']=2009
s0910= s0910.set_index(['Player','Season'])


#advanced

sa_0910 = preclean(sa_0910)


sa_0910['Season']=2009
sa_0910= sa_0910.set_index(['Player','Season'])
sa_0910= sa_0910.drop(columns='Tm')



#shootout

ss_0910=ss_0910.reset_index()

ss_0910['Season']=2009

ss_0910=ss_0910.set_index(['Player','Season'])

ss_0910= ss_0910.drop(columns=['Tm','index'])

ss_0910= ss_0910.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})


#merge and clean

skaters0910= s0910.merge(sa_0910, how='inner', on=['Player','Season']).merge(ss_0910, how='left', on=['Player','Season'])


skaters0910= skaters0910[skaters0910.index.get_level_values('Player') != 'Player']


replace_nulls= skaters0910[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters0910[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters0910= skaters0910.drop(columns=['Age_y','Pos_y','GP_y'])

skaters0910
# Out:
#                          Age_x   Tm Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Player            Season                                                  ...
# Justin Abdelkader 2009      22  DET    LW   50   3   3   6  -11  35 -0.3  ...
# Craig Adams       2009      32  PIT    RW   82   0  10  10   -5  72 -0.8  ...
# Maxim Afinogenov  2009      30  ATL    RW   82  24  37  61  -17  46  5.7  ...
# Andrew Alberts    2009      28  TOT     D   76   3   9  12    6  87  3.1  ...
#                   2009      28  CAR     D   62   2   8  10    7  74  2.7  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
# Greg Zanon        2009      29  MIN     D   81   2  13  15  -10  36  3.2  ...
# Henrik Zetterberg 2009      29  DET    LW   74  23  47  70   12  26  8.2  ...
# Vladimir Zharkov  2009      22  NJD    RW   40   0  10  10    2   8  0.5  ...
# Marek Zidlicky    2009      32  MIN     D   78   6  37  43  -16  67  6.3  ...
# Dainius Zubrus    2009      31  NJD    RW   51  10  17  27    4  28  2.9  ...
#
#                                        TOI/60   TOI(EV)  TK  GV SAtt. Thru%  \
# Player            Season
# Justin Abdelkader 2009               10:35:00  09:36:00   7   7   141    56
# Craig Adams       2009               10:57:00  08:11:00  22  12   144  56.3
# Maxim Afinogenov  2009               17:23:00  14:12:00  65  63   321  56.4
# Andrew Alberts    2009               15:13:00  13:10:00  19  39   129  37.2
#                   2009               15:13:00  13:10:00  19  39   129  37.2
# ...                                       ...       ...  ..  ..   ...   ...
# Greg Zanon        2009               22:22:00  18:45:00  25  39   146  40.4
# Henrik Zetterberg 2009               19:45:00  15:22:00  51  46   515  58.3
# Vladimir Zharkov  2009               11:26:00  10:05:00   9  14   100    54
# Marek Zidlicky    2009    1900-01-01 00:09:00  17:36:00  32  52   250  46.4
# Dainius Zubrus    2009               16:29:00  13:45:00  18  21   131  65.6
#
#                          SOT_Att SOT_Scored SOT_Saved SOT_Pct
# Player            Season
# Justin Abdelkader 2009         0          0         0     0.0
# Craig Adams       2009         0          0         0     0.0
# Maxim Afinogenov  2009         3          0         3     0.0
# Andrew Alberts    2009         0          0         0     0.0
#                   2009         0          0         0     0.0
# ...                          ...        ...       ...     ...
# Greg Zanon        2009         0          0         0     0.0
# Henrik Zetterberg 2009        11          2         9    18.2
# Vladimir Zharkov  2009         0          0         0     0.0
# Marek Zidlicky    2009         7          2         5    28.6
# Dainius Zubrus    2009         0          0         0     0.0
#
# [1044 rows x 49 columns]

# %%
#save

skaters0910.to_csv('./Clean/skaters2009.csv')

# %% [markdown]
# #                        2010-2011 PLAYER STATS

# %%
#load
s1011=pd.DataFrame()
s1011= pd.read_excel('./Stats/2010-11/2010-11skaters.xlsx', engine= 'openpyxl')

sa_1011=pd.DataFrame()
sa_1011=pd.read_excel('./Stats/2010-11/2010-11skaters_adv.xlsx', engine='openpyxl')

ss_1011=pd.DataFrame()
ss_1011=pd.read_excel('./Stats/2010-11/2010-11skaters_shootout.xlsx', engine='openpyxl')

# %%
#regular stats
s1011= preclean(s1011)
s1011['Season']=2010
s1011= s1011.set_index(['Season','Player'])
s1011.head()
# Out:
# 0                        Age   Tm Pos  GP   G   A PTS  +/- PIM   PS  ... SH  \
# Season Player                                                        ...
# 2010   Justin Abdelkader  23  DET  LW  74   7  12  19   15  61  1.7  ...  1
#        Luke Adam          20  BUF  LW  19   3   1   4   -6  12  0.1  ...  0
#        Craig Adams        33  PIT  RW  80   4  11  15   -5  76  0.2  ...  2
#        Andrew Alberts     29  VAN   D  42   1   6   7    0  41  1.5  ...  0
#        Daniel Alfredsson  38  OTT  RW  54  14  17  31  -19  18  2.7  ...  0
#
# 0                           S    S%   TOI      ATOI BLK  HIT  FOW  FOL   FO%
# Season Player
# 2010   Justin Abdelkader  129   5.4   910  12:18:00  39  188  227  203  52.8
#        Luke Adam           31   9.7   213  11:13:00   5   17   41   78  34.5
#        Craig Adams         90   4.4   975  12:11:00  64  171  194  271  41.7
#        Andrew Alberts      21   4.8   637  15:10:00  49  113    0    0   NaN
#        Daniel Alfredsson   96  14.6  1041  19:17:00  21   41    2   10  16.7
#
# [5 rows x 26 columns]

# %%
#advanced

sa_1011 = preclean(sa_1011)
sa_1011.head()

sa_1011['Season']=2010
sa_1011= sa_1011.set_index(['Season','Player'])
#sa_1011= sa_1011.drop(columns='Tm')
sa_1011.head()
# Out:
# 0                        Age   Tm Pos  GP   CF   CA   CF% CF% rel   FF   FA  \
# Season Player
# 2010   Justin Abdelkader  23  DET  LW  74  765  628  54.9    -0.4  599  478
#        Luke Adam          20  BUF  LW  19  153  201  43.2      -6  118  156
#        Craig Adams        33  PIT  RW  80  565  647  46.6    -7.8  424  460
#        Andrew Alberts     29  VAN   D  42  470  532  46.9    -7.3  322  377
#        Daniel Alfredsson  38  OTT  RW  54  655  702  48.3    -2.5  484  541
#
# 0                         ... oiSV%    PDO  oZS%  dZS%    TOI/60   TOI(EV)  \
# Season Player             ...
# 2010   Justin Abdelkader  ...  93.6  101.9  58.8  41.2  12:18:00  10:26:00
#        Luke Adam          ...  92.6   97.1  53.6  46.4  11:13:00  09:37:00
#        Craig Adams        ...  91.1   96.8  49.4  50.6  12:11:00  09:05:00
#        Andrew Alberts     ...  92.1  101.4  40.6  59.4  15:08:00  13:20:00
#        Daniel Alfredsson  ...  88.1   96.3  52.8  47.2  19:17:00  14:11:00
#
# 0                         TK  GV SAtt. Thru%
# Season Player
# 2010   Justin Abdelkader  17  20   226  57.1
#        Luke Adam           2   7    50    62
#        Craig Adams        24  15   138  65.2
#        Andrew Alberts      7  19    53  39.6
#        Daniel Alfredsson  45  46   187  51.3
#
# [5 rows x 23 columns]

# %%
#shootout

ss_1011=ss_1011.reset_index()

ss_1011['Season']=2010

ss_1011=ss_1011.set_index(['Season','Player'])

ss_1011= ss_1011.drop(columns=['Tm','index'])

ss_1011= ss_1011.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})

ss_1011.head()
# Out:
#                          SOT_Att SOT_Scored SOT_Saved SOT_Pct
# Season Player
# 2010   Dan Boyle               3          3         0     100
#        Viktor Stalberg         2          2         0     100
#        Alexandre Burrows       2          2         0     100
#        Colby Armstrong         2          2         0     100
#        Jochen Hecht            1          1         0     100

# %%
#merge and clean

skaters1011= s1011.merge(sa_1011, how='inner', on=['Season','Player']).merge(ss_1011, how='left', on=['Season','Player'])


skaters1011= skaters1011[skaters1011.index.get_level_values('Player') != 'Player']


replace_nulls= skaters1011[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters1011[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters1011
# Out:
#                          Age_x Tm_x Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Season Player                                                             ...
# 2010   Justin Abdelkader    23  DET    LW   74   7  12  19   15  61  1.7  ...
#        Luke Adam            20  BUF    LW   19   3   1   4   -6  12  0.1  ...
#        Craig Adams          33  PIT    RW   80   4  11  15   -5  76  0.2  ...
#        Andrew Alberts       29  VAN     D   42   1   6   7    0  41  1.5  ...
#        Daniel Alfredsson    38  OTT    RW   54  14  17  31  -19  18  2.7  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
#        Marek Zidlicky       33  MIN     D   46   7  17  24   -6  30  4.2  ...
#        Mike Zigomanis       30  TOR     C    8   0   1   1    0   4    0  ...
#        Andrei Zubarev       23  ATL     D    4   0   1   1   -4   4 -0.2  ...
#        Dainius Zubrus       32  NJD    RW   79  13  17  30  -11  53  2.6  ...
#        Mats Zuccarello      23  NYR    LW   42   6  17  23    3   4  2.4  ...
#
#                             TOI/60   TOI(EV)  TK  GV SAtt. Thru% SOT_Att  \
# Season Player
# 2010   Justin Abdelkader  12:18:00  10:26:00  17  20   226  57.1       0
#        Luke Adam          11:13:00  09:37:00   2   7    50    62       0
#        Craig Adams        12:11:00  09:05:00  24  15   138  65.2       0
#        Andrew Alberts     15:08:00  13:20:00   7  19    53  39.6       0
#        Daniel Alfredsson  19:17:00  14:11:00  45  46   187  51.3       3
# ...                            ...       ...  ..  ..   ...   ...     ...
#        Marek Zidlicky     21:46:00  16:16:00  14  33   141  37.6       1
#        Mike Zigomanis     06:59:00  04:53:00   4   1    10    70       0
#        Andrei Zubarev     20:05:00  18:03:00   2   0     4    50       0
#        Dainius Zubrus     17:09:00  13:58:00  33  30   190  60.5       0
#        Mats Zuccarello    14:10:00  11:30:00  16   6   121  61.2       9
#
#                          SOT_Scored SOT_Saved SOT_Pct
# Season Player
# 2010   Justin Abdelkader          0         0     0.0
#        Luke Adam                  0         0     0.0
#        Craig Adams                0         0     0.0
#        Andrew Alberts             0         0     0.0
#        Daniel Alfredsson          0         3     0.0
# ...                             ...       ...     ...
#        Marek Zidlicky             0         1     0.0
#        Mike Zigomanis             0         0     0.0
#        Andrei Zubarev             0         0     0.0
#        Dainius Zubrus             0         0     0.0
#        Mats Zuccarello            5         4    55.6
#
# [1038 rows x 53 columns]

# %%
#load
s1011=pd.DataFrame()
s1011= pd.read_excel('./Stats/2010-11/2010-11skaters.xlsx', engine= 'openpyxl')

sa_1011=pd.DataFrame()
sa_1011=pd.read_excel('./Stats/2010-11/2010-11skaters_adv.xlsx', engine='openpyxl')

ss_1011=pd.DataFrame()
ss_1011=pd.read_excel('./Stats/2010-11/2010-11skaters_shootout.xlsx', engine='openpyxl')


#regular stats
s1011= preclean(s1011)
s1011['Season']=2010
s1011= s1011.set_index(['Season','Player'])


#advanced

sa_1011 = preclean(sa_1011)


sa_1011['Season']=2010
sa_1011= sa_1011.set_index(['Season','Player'])
sa_1011= sa_1011.drop(columns='Tm')



#shootout

ss_1011=ss_1011.reset_index()

ss_1011['Season']=2010

ss_1011=ss_1011.set_index(['Season','Player'])

ss_1011= ss_1011.drop(columns=['Tm','index'])

ss_1011= ss_1011.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})


#merge

skaters1011= s1011.merge(sa_1011, how='inner', on=['Season','Player']).merge(ss_1011, how='left', on=['Season','Player'])


#clean some more

skaters1011= skaters1011[skaters1011.index.get_level_values('Player') != 'Player']


replace_nulls= skaters1011[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters1011[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters1011= skaters1011.drop(columns=['Age_y','Pos_y','GP_y'])

skaters1011
# Out:
#                          Age_x   Tm Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Season Player                                                             ...
# 2010   Justin Abdelkader    23  DET    LW   74   7  12  19   15  61  1.7  ...
#        Luke Adam            20  BUF    LW   19   3   1   4   -6  12  0.1  ...
#        Craig Adams          33  PIT    RW   80   4  11  15   -5  76  0.2  ...
#        Andrew Alberts       29  VAN     D   42   1   6   7    0  41  1.5  ...
#        Daniel Alfredsson    38  OTT    RW   54  14  17  31  -19  18  2.7  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
#        Marek Zidlicky       33  MIN     D   46   7  17  24   -6  30  4.2  ...
#        Mike Zigomanis       30  TOR     C    8   0   1   1    0   4    0  ...
#        Andrei Zubarev       23  ATL     D    4   0   1   1   -4   4 -0.2  ...
#        Dainius Zubrus       32  NJD    RW   79  13  17  30  -11  53  2.6  ...
#        Mats Zuccarello      23  NYR    LW   42   6  17  23    3   4  2.4  ...
#
#                             TOI/60   TOI(EV)  TK  GV SAtt. Thru% SOT_Att  \
# Season Player
# 2010   Justin Abdelkader  12:18:00  10:26:00  17  20   226  57.1       0
#        Luke Adam          11:13:00  09:37:00   2   7    50    62       0
#        Craig Adams        12:11:00  09:05:00  24  15   138  65.2       0
#        Andrew Alberts     15:08:00  13:20:00   7  19    53  39.6       0
#        Daniel Alfredsson  19:17:00  14:11:00  45  46   187  51.3       3
# ...                            ...       ...  ..  ..   ...   ...     ...
#        Marek Zidlicky     21:46:00  16:16:00  14  33   141  37.6       1
#        Mike Zigomanis     06:59:00  04:53:00   4   1    10    70       0
#        Andrei Zubarev     20:05:00  18:03:00   2   0     4    50       0
#        Dainius Zubrus     17:09:00  13:58:00  33  30   190  60.5       0
#        Mats Zuccarello    14:10:00  11:30:00  16   6   121  61.2       9
#
#                          SOT_Scored SOT_Saved SOT_Pct
# Season Player
# 2010   Justin Abdelkader          0         0     0.0
#        Luke Adam                  0         0     0.0
#        Craig Adams                0         0     0.0
#        Andrew Alberts             0         0     0.0
#        Daniel Alfredsson          0         3     0.0
# ...                             ...       ...     ...
#        Marek Zidlicky             0         1     0.0
#        Mike Zigomanis             0         0     0.0
#        Andrei Zubarev             0         0     0.0
#        Dainius Zubrus             0         0     0.0
#        Mats Zuccarello            5         4    55.6
#
# [1038 rows x 49 columns]

# %%
#load
s1011=pd.DataFrame()
s1011= pd.read_excel('./Stats/2010-11/2010-11skaters.xlsx', engine= 'openpyxl')

sa_1011=pd.DataFrame()
sa_1011=pd.read_excel('./Stats/2010-11/2010-11skaters_adv.xlsx', engine='openpyxl')

ss_1011=pd.DataFrame()
ss_1011=pd.read_excel('./Stats/2010-11/2010-11skaters_shootout.xlsx', engine='openpyxl')


#regular stats
s1011= preclean(s1011)
s1011['Season']=2010
s1011= s1011.set_index(['Player','Season'])


#advanced

sa_1011 = preclean(sa_1011)


sa_1011['Season']=2010
sa_1011= sa_1011.set_index(['Player','Season'])
sa_1011= sa_1011.drop(columns='Tm')



#shootout

ss_1011=ss_1011.reset_index()

ss_1011['Season']=2010

ss_1011=ss_1011.set_index(['Player','Season'])

ss_1011= ss_1011.drop(columns=['Tm','index'])

ss_1011= ss_1011.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})


#merge and clean

skaters1011= s1011.merge(sa_1011, how='inner', on=['Player','Season']).merge(ss_1011, how='left', on=['Player','Season'])


skaters1011= skaters1011[skaters1011.index.get_level_values('Player') != 'Player']


replace_nulls= skaters1011[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters1011[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters1011= skaters1011.drop(columns=['Age_y','Pos_y','GP_y'])

skaters1011
# Out:
#                          Age_x   Tm Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Player            Season                                                  ...
# Justin Abdelkader 2010      23  DET    LW   74   7  12  19   15  61  1.7  ...
# Luke Adam         2010      20  BUF    LW   19   3   1   4   -6  12  0.1  ...
# Craig Adams       2010      33  PIT    RW   80   4  11  15   -5  76  0.2  ...
# Andrew Alberts    2010      29  VAN     D   42   1   6   7    0  41  1.5  ...
# Daniel Alfredsson 2010      38  OTT    RW   54  14  17  31  -19  18  2.7  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
# Marek Zidlicky    2010      33  MIN     D   46   7  17  24   -6  30  4.2  ...
# Mike Zigomanis    2010      30  TOR     C    8   0   1   1    0   4    0  ...
# Andrei Zubarev    2010      23  ATL     D    4   0   1   1   -4   4 -0.2  ...
# Dainius Zubrus    2010      32  NJD    RW   79  13  17  30  -11  53  2.6  ...
# Mats Zuccarello   2010      23  NYR    LW   42   6  17  23    3   4  2.4  ...
#
#                             TOI/60   TOI(EV)  TK  GV SAtt. Thru% SOT_Att  \
# Player            Season
# Justin Abdelkader 2010    12:18:00  10:26:00  17  20   226  57.1       0
# Luke Adam         2010    11:13:00  09:37:00   2   7    50    62       0
# Craig Adams       2010    12:11:00  09:05:00  24  15   138  65.2       0
# Andrew Alberts    2010    15:08:00  13:20:00   7  19    53  39.6       0
# Daniel Alfredsson 2010    19:17:00  14:11:00  45  46   187  51.3       3
# ...                            ...       ...  ..  ..   ...   ...     ...
# Marek Zidlicky    2010    21:46:00  16:16:00  14  33   141  37.6       1
# Mike Zigomanis    2010    06:59:00  04:53:00   4   1    10    70       0
# Andrei Zubarev    2010    20:05:00  18:03:00   2   0     4    50       0
# Dainius Zubrus    2010    17:09:00  13:58:00  33  30   190  60.5       0
# Mats Zuccarello   2010    14:10:00  11:30:00  16   6   121  61.2       9
#
#                          SOT_Scored SOT_Saved SOT_Pct
# Player            Season
# Justin Abdelkader 2010            0         0     0.0
# Luke Adam         2010            0         0     0.0
# Craig Adams       2010            0         0     0.0
# Andrew Alberts    2010            0         0     0.0
# Daniel Alfredsson 2010            0         3     0.0
# ...                             ...       ...     ...
# Marek Zidlicky    2010            0         1     0.0
# Mike Zigomanis    2010            0         0     0.0
# Andrei Zubarev    2010            0         0     0.0
# Dainius Zubrus    2010            0         0     0.0
# Mats Zuccarello   2010            5         4    55.6
#
# [1038 rows x 49 columns]

# %%
#save

skaters1011.to_csv('./Clean/skaters2010.csv')

# %% [markdown]
# #                        2011-2012 PLAYER STATS

# %%
#load
s1112=pd.DataFrame()
s1112= pd.read_excel('./Stats/2011-12/2011-12skaters.xlsx', engine= 'openpyxl')

sa_1112=pd.DataFrame()
sa_1112=pd.read_excel('./Stats/2011-12/2011-12skaters_adv.xlsx', engine='openpyxl')

ss_1112=pd.DataFrame()
ss_1112=pd.read_excel('./Stats/2011-12/2011-12skaters_shootout.xlsx', engine='openpyxl')


#regular stats 
s1112= preclean(s1112)
s1112['Season']=2011
s1112= s1112.set_index(['Season','Player'])


#advanced

sa_1112 = preclean(sa_1112)


sa_1112['Season']=2011
sa_1112= sa_1112.set_index(['Season','Player'])
sa_1112= sa_1112.drop(columns='Tm')



#shootout

ss_1112=ss_1112.reset_index()

ss_1112['Season']=2011

ss_1112=ss_1112.set_index(['Season','Player'])

ss_1112= ss_1112.drop(columns=['Tm','index'])

ss_1112= ss_1112.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})


skaters1112= s1112.merge(sa_1112, how='inner', on=['Season','Player']).merge(ss_1112, how='left', on=['Season','Player'])


skaters1112= skaters1112[skaters1112.index.get_level_values('Player') != 'Player']


replace_nulls= skaters1112[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters1112[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters1112= skaters1112.drop(columns=['Age_y','Pos_y','GP_y'])

skaters1112
# Out:
#                          Age_x   Tm Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Season Player                                                             ...
# 2011   Justin Abdelkader    24  DET    LW   81   8  14  22    4  62  1.6  ...
#        Luke Adam            21  BUF    LW   52  10  10  20   -6  14    2  ...
#        Craig Adams          34  PIT    RW   82   5  13  18   -6  34  0.6  ...
#        Andrew Alberts       30  VAN     D   44   2   1   3    4  40  1.4  ...
#        Daniel Alfredsson    39  OTT    RW   75  27  32  59   16  18  7.5  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
#        Marek Zidlicky       34  NJD     D   22   2   6   8    0  10  1.8  ...
#        Harry Zolnierczyk    24  PHI    LW   37   3   3   6  -11  35    0  ...
#        Dainius Zubrus       33  NJD    RW   82  17  27  44    7  34    5  ...
#        Mats Zuccarello      24  NYR    LW   10   2   1   3    0   6  0.4  ...
#        Jason Zucker         20  MIN    LW    6   0   2   2   -2   2    0  ...
#
#                             TOI/60   TOI(EV)  TK  GV SAtt. Thru% SOT_Att  \
# Season Player
# 2011   Justin Abdelkader  12:19:00  10:46:00  16  14   196  61.7       0
#        Luke Adam          12:24:00  10:46:00  24  16   167  53.3       0
#        Craig Adams        11:17:00  08:24:00  13   7   130  58.5       0
#        Andrew Alberts     14:18:00  13:04:00  13  16    61  31.1       0
#        Daniel Alfredsson  18:57:00  14:41:00  50  58   337  56.7       6
# ...                            ...       ...  ..  ..   ...   ...     ...
#        Marek Zidlicky     21:20:00  17:29:00  14  44   159    44       1
#        Harry Zolnierczyk  07:42:00  07:19:00   4   3    81  60.5       0
#        Dainius Zubrus     18:41:00  14:52:00  34  23   171  63.7       0
#        Mats Zuccarello    10:03:00  06:58:00   2   2    19  52.6       1
#        Jason Zucker       11:02:00  10:44:00   2   2    16  62.5       0
#
#                          SOT_Scored SOT_Saved SOT_Pct
# Season Player
# 2011   Justin Abdelkader          0         0     0.0
#        Luke Adam                  0         0     0.0
#        Craig Adams                0         0     0.0
#        Andrew Alberts             0         0     0.0
#        Daniel Alfredsson          5         1    83.3
# ...                             ...       ...     ...
#        Marek Zidlicky             0         1     0.0
#        Harry Zolnierczyk          0         0     0.0
#        Dainius Zubrus             0         0     0.0
#        Mats Zuccarello            0         1     0.0
#        Jason Zucker               0         0     0.0
#
# [1038 rows x 52 columns]

# %%
skaters1112.columns
# Out:
# Index(['Age_x', 'Tm', 'Pos_x', 'GP_x', 'G', 'A', 'PTS', '+/-', 'PIM', 'PS',
#        'EV', 'PP', 'SH', 'GW', 'EV', 'PP', 'SH', 'S', 'S%', 'TOI', 'ATOI',
#        'BLK', 'HIT', 'FOW', 'FOL', 'FO%', 'Age_y', 'Pos_y', 'GP_y', 'CF', 'CA',
#        'CF%', 'CF% rel', 'FF', 'FA', 'FF%', 'FF% rel', 'oiSH%', 'oiSV%', 'PDO',
#        'oZS%', 'dZS%', 'TOI/60', 'TOI(EV)', 'TK', 'GV', 'SAtt.', 'Thru%',
#        'SOT_Att', 'SOT_Scored', 'SOT_Saved', 'SOT_Pct'],
#       dtype='object')

# %%
skaters1112= skaters1112.drop(columns=['Age_y','Pos_y','GP_y'])
skaters1112
# Out:
#                          Age_x   Tm Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Season Player                                                             ...
# 2011   Justin Abdelkader    24  DET    LW   81   8  14  22    4  62  1.6  ...
#        Luke Adam            21  BUF    LW   52  10  10  20   -6  14    2  ...
#        Craig Adams          34  PIT    RW   82   5  13  18   -6  34  0.6  ...
#        Andrew Alberts       30  VAN     D   44   2   1   3    4  40  1.4  ...
#        Daniel Alfredsson    39  OTT    RW   75  27  32  59   16  18  7.5  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
#        Marek Zidlicky       34  NJD     D   22   2   6   8    0  10  1.8  ...
#        Harry Zolnierczyk    24  PHI    LW   37   3   3   6  -11  35    0  ...
#        Dainius Zubrus       33  NJD    RW   82  17  27  44    7  34    5  ...
#        Mats Zuccarello      24  NYR    LW   10   2   1   3    0   6  0.4  ...
#        Jason Zucker         20  MIN    LW    6   0   2   2   -2   2    0  ...
#
#                             TOI/60   TOI(EV)  TK  GV SAtt. Thru% SOT_Att  \
# Season Player
# 2011   Justin Abdelkader  12:19:00  10:46:00  16  14   196  61.7       0
#        Luke Adam          12:24:00  10:46:00  24  16   167  53.3       0
#        Craig Adams        11:17:00  08:24:00  13   7   130  58.5       0
#        Andrew Alberts     14:18:00  13:04:00  13  16    61  31.1       0
#        Daniel Alfredsson  18:57:00  14:41:00  50  58   337  56.7       6
# ...                            ...       ...  ..  ..   ...   ...     ...
#        Marek Zidlicky     21:20:00  17:29:00  14  44   159    44       1
#        Harry Zolnierczyk  07:42:00  07:19:00   4   3    81  60.5       0
#        Dainius Zubrus     18:41:00  14:52:00  34  23   171  63.7       0
#        Mats Zuccarello    10:03:00  06:58:00   2   2    19  52.6       1
#        Jason Zucker       11:02:00  10:44:00   2   2    16  62.5       0
#
#                          SOT_Scored SOT_Saved SOT_Pct
# Season Player
# 2011   Justin Abdelkader          0         0     0.0
#        Luke Adam                  0         0     0.0
#        Craig Adams                0         0     0.0
#        Andrew Alberts             0         0     0.0
#        Daniel Alfredsson          5         1    83.3
# ...                             ...       ...     ...
#        Marek Zidlicky             0         1     0.0
#        Harry Zolnierczyk          0         0     0.0
#        Dainius Zubrus             0         0     0.0
#        Mats Zuccarello            0         1     0.0
#        Jason Zucker               0         0     0.0
#
# [1038 rows x 49 columns]

# %%
#load
s1112=pd.DataFrame()
s1112= pd.read_excel('./Stats/2011-12/2011-12skaters.xlsx', engine= 'openpyxl')

sa_1112=pd.DataFrame()
sa_1112=pd.read_excel('./Stats/2011-12/2011-12skaters_adv.xlsx', engine='openpyxl')

ss_1112=pd.DataFrame()
ss_1112=pd.read_excel('./Stats/2011-12/2011-12skaters_shootout.xlsx', engine='openpyxl')


#regular stats
s1112= preclean(s1112)
s1112['Season']=2011
s1112= s1112.set_index(['Player','Season'])


#advanced

sa_1112 = preclean(sa_1112)


sa_1112['Season']=2011
sa_1112= sa_1112.set_index(['Player','Season'])
sa_1112= sa_1112.drop(columns='Tm')



#shootout

ss_1112=ss_1112.reset_index()

ss_1112['Season']=2011

ss_1112=ss_1112.set_index(['Player','Season'])

ss_1112= ss_1112.drop(columns=['Tm','index'])

ss_1112= ss_1112.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})


#merge and clean

skaters1112= s1112.merge(sa_1112, how='inner', on=['Player','Season']).merge(ss_1112, how='left', on=['Player','Season'])


skaters1112= skaters1112[skaters1112.index.get_level_values('Player') != 'Player']


replace_nulls= skaters1112[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters1112[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters1112= skaters1112.drop(columns=['Age_y','Pos_y','GP_y'])

skaters1112
# Out:
#                          Age_x   Tm Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Player            Season                                                  ...
# Justin Abdelkader 2011      24  DET    LW   81   8  14  22    4  62  1.6  ...
# Luke Adam         2011      21  BUF    LW   52  10  10  20   -6  14    2  ...
# Craig Adams       2011      34  PIT    RW   82   5  13  18   -6  34  0.6  ...
# Andrew Alberts    2011      30  VAN     D   44   2   1   3    4  40  1.4  ...
# Daniel Alfredsson 2011      39  OTT    RW   75  27  32  59   16  18  7.5  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
# Marek Zidlicky    2011      34  NJD     D   22   2   6   8    0  10  1.8  ...
# Harry Zolnierczyk 2011      24  PHI    LW   37   3   3   6  -11  35    0  ...
# Dainius Zubrus    2011      33  NJD    RW   82  17  27  44    7  34    5  ...
# Mats Zuccarello   2011      24  NYR    LW   10   2   1   3    0   6  0.4  ...
# Jason Zucker      2011      20  MIN    LW    6   0   2   2   -2   2    0  ...
#
#                             TOI/60   TOI(EV)  TK  GV SAtt. Thru% SOT_Att  \
# Player            Season
# Justin Abdelkader 2011    12:19:00  10:46:00  16  14   196  61.7       0
# Luke Adam         2011    12:24:00  10:46:00  24  16   167  53.3       0
# Craig Adams       2011    11:17:00  08:24:00  13   7   130  58.5       0
# Andrew Alberts    2011    14:18:00  13:04:00  13  16    61  31.1       0
# Daniel Alfredsson 2011    18:57:00  14:41:00  50  58   337  56.7       6
# ...                            ...       ...  ..  ..   ...   ...     ...
# Marek Zidlicky    2011    21:20:00  17:29:00  14  44   159    44       1
# Harry Zolnierczyk 2011    07:42:00  07:19:00   4   3    81  60.5       0
# Dainius Zubrus    2011    18:41:00  14:52:00  34  23   171  63.7       0
# Mats Zuccarello   2011    10:03:00  06:58:00   2   2    19  52.6       1
# Jason Zucker      2011    11:02:00  10:44:00   2   2    16  62.5       0
#
#                          SOT_Scored SOT_Saved SOT_Pct
# Player            Season
# Justin Abdelkader 2011            0         0     0.0
# Luke Adam         2011            0         0     0.0
# Craig Adams       2011            0         0     0.0
# Andrew Alberts    2011            0         0     0.0
# Daniel Alfredsson 2011            5         1    83.3
# ...                             ...       ...     ...
# Marek Zidlicky    2011            0         1     0.0
# Harry Zolnierczyk 2011            0         0     0.0
# Dainius Zubrus    2011            0         0     0.0
# Mats Zuccarello   2011            0         1     0.0
# Jason Zucker      2011            0         0     0.0
#
# [1038 rows x 49 columns]

# %%
#save

skaters1112.to_csv('./Clean/skaters2011.csv')

# %% [markdown]
# #                 2012-2013 PLAYER STATS

# %%
#load
s1213=pd.DataFrame()
s1213= pd.read_excel('./Stats/2012-13/2012-13skaters.xlsx', engine= 'openpyxl')

sa_1213=pd.DataFrame()
sa_1213=pd.read_excel('./Stats/2012-13/2012-13skaters_adv.xlsx', engine='openpyxl')

ss_1213=pd.DataFrame()
ss_1213=pd.read_excel('./Stats/2012-13/2012-13skaters_shootout.xlsx', engine='openpyxl')


#regular stats
s1213= preclean(s1213)
s1213['Season']=2012
s1213= s1213.set_index(['Player','Season'])


#advanced

sa_1213 = preclean(sa_1213)


sa_1213['Season']=2012
sa_1213= sa_1213.set_index(['Player','Season'])
sa_1213= sa_1213.drop(columns='Tm')



#shootout

ss_1213=ss_1213.reset_index()

ss_1213['Season']=2012

ss_1213=ss_1213.set_index(['Player','Season'])

ss_1213= ss_1213.drop(columns=['Tm','index'])

ss_1213= ss_1213.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})


#merge and clean

skaters1213= s1213.merge(sa_1213, how='inner', on=['Player','Season']).merge(ss_1213, how='left', on=['Player','Season'])


skaters1213= skaters1213[skaters1213.index.get_level_values('Player') != 'Player']


replace_nulls= skaters1213[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters1213[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters1213= skaters1213.drop(columns=['Age_y','Pos_y','GP_y'])

skaters1213
# Out:
#                          Age_x   Tm Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Player            Season                                                  ...
# Justin Abdelkader 2012      25  DET    LW   48  10   3  13    6  34  1.7  ...
# Luke Adam         2012      22  BUF    LW    4   1   0   1    1   2  0.2  ...
# Craig Adams       2012      35  PIT    RW   48   3   6   9   -1  28  0.2  ...
# Jason Akeson      2012      22  PHI     C    1   1   0   1    2   0  0.3  ...
# Andrew Alberts    2012      31  VAN     D   24   0   1   1   -7  32 -0.1  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
# Marek Zidlicky    2012      35  NJD     D   48   4  15  19  -12  38    3  ...
# Harry Zolnierczyk 2012      25  PHI    LW    7   0   1   1    0  36    0  ...
# Dainius Zubrus    2012      34  NJD    RW   22   2   7   9   -3  12  0.6  ...
# Mats Zuccarello   2012      25  NYR    LW   15   3   5   8   10   8  1.3  ...
# Jason Zucker      2012      21  MIN    LW   20   4   1   5    4   8  0.8  ...
#
#                             TOI/60   TOI(EV)  TK  GV SAtt. Thru% SOT_Att  \
# Player            Season
# Justin Abdelkader 2012    14:49:00  13:38:00  10  10   147  65.3       0
# Luke Adam         2012    09:48:00  09:25:00   0   0     5    40       0
# Craig Adams       2012    11:10:00  08:28:00   5   7    71  64.8       0
# Jason Akeson      2012    12:23:00  12:23:00   2   0     3  66.7       0
# Andrew Alberts    2012    15:11:00  13:49:00   5   7    40  37.5       0
# ...                            ...       ...  ..  ..   ...   ...     ...
# Marek Zidlicky    2012       0.875  17:09:00  10  31   232  43.5       1
# Harry Zolnierczyk 2012    07:22:00  07:19:00   1   0     9  44.4       0
# Dainius Zubrus    2012    16:47:00  13:56:00   6   6    39  56.4       0
# Mats Zuccarello   2012    16:25:00  14:00:00   6   5    52  51.9       2
# Jason Zucker      2012    11:15:00  10:39:00   4   7    58  58.6       0
#
#                          SOT_Scored SOT_Saved SOT_Pct
# Player            Season
# Justin Abdelkader 2012            0         0     0.0
# Luke Adam         2012            0         0     0.0
# Craig Adams       2012            0         0     0.0
# Jason Akeson      2012            0         0     0.0
# Andrew Alberts    2012            0         0     0.0
# ...                             ...       ...     ...
# Marek Zidlicky    2012            0         1     0.0
# Harry Zolnierczyk 2012            0         0     0.0
# Dainius Zubrus    2012            0         0     0.0
# Mats Zuccarello   2012            1         1    50.0
# Jason Zucker      2012            0         0     0.0
#
# [949 rows x 49 columns]

# %%
#save

skaters1213.to_csv('./Clean/skaters2012.csv')

# %% [markdown]
# #                      2013-2014 PLAYER STATS

# %%
#load
s1314=pd.DataFrame()
s1314= pd.read_excel('./Stats/2013-14/2013-14skaters.xlsx', engine= 'openpyxl')

sa_1314=pd.DataFrame()
sa_1314=pd.read_excel('./Stats/2013-14/2013-14skaters_adv.xlsx', engine='openpyxl')

ss_1314=pd.DataFrame()
ss_1314=pd.read_excel('./Stats/2013-14/2013-14skaters_shootout.xlsx', engine='openpyxl')


#regular stats
s1314= preclean(s1314)
s1314['Season']=2013
s1314= s1314.set_index(['Player','Season'])


#advanced

sa_1314 = preclean(sa_1314)


sa_1314['Season']=2013
sa_1314= sa_1314.set_index(['Player','Season'])
sa_1314= sa_1314.drop(columns='Tm')



#shootout

ss_1314=ss_1314.reset_index()

ss_1314['Season']=2013

ss_1314=ss_1314.set_index(['Player','Season'])

ss_1314= ss_1314.drop(columns=['Tm','index'])

ss_1314= ss_1314.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})


#merge

skaters1314= s1314.merge(sa_1314, how='inner', on=['Player','Season']).merge(ss_1314, how='left', on=['Player','Season'])


#clean some more

skaters1314= skaters1314[skaters1314.index.get_level_values('Player') != 'Player']


replace_nulls= skaters1314[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters1314[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters1314= skaters1314.drop(columns=['Age_y','Pos_y','GP_y'])

skaters1314
# Out:
#                          Age_x   Tm Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Player            Season                                                  ...
# Spencer Abbott    2013      25  TOR    RW    1   0   0   0   -2   0 -0.1  ...
# Justin Abdelkader 2013      26  DET    LW   70  10  18  28    2  31  2.6  ...
# Will Acton        2013      26  EDM     C   30   3   2   5   -2  21  0.4  ...
# Luke Adam         2013      23  BUF     C   12   1   0   1    0   4    0  ...
# Craig Adams       2013      36  PIT    RW   82   5   6  11  -16  46 -0.6  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
# Marek Zidlicky    2013      36  NJD     D   81  12  30  42   -3  60  8.3  ...
# Harry Zolnierczyk 2013      26  PIT    LW   13   2   0   2    0  12  0.2  ...
# Dainius Zubrus    2013      35  NJD     C   82  13  13  26    1  46  2.4  ...
# Mats Zuccarello   2013      26  NYR    LW   77  19  40  59   11  32  7.3  ...
# Jason Zucker      2013      22  MIN    LW   21   4   1   5    2   2  0.6  ...
#
#                             TOI/60   TOI(EV)  TK  GV SAtt. Thru% SOT_Att  \
# Player            Season
# Spencer Abbott    2013    05:16:00  05:16:00   0   0     2   100       0
# Justin Abdelkader 2013    15:17:00  13:43:00  21  15   222  65.8       0
# Will Acton        2013    08:08:00  06:06:00  15   4    37  48.6       0
# Luke Adam         2013    12:50:00  12:16:00   1   0    35  45.7       1
# Craig Adams       2013    12:28:00  09:24:00  15  16   125  58.4       0
# ...                            ...       ...  ..  ..   ...   ...     ...
# Marek Zidlicky    2013    21:39:00  18:23:00  19  58   259  49.4       1
# Harry Zolnierczyk 2013    10:08:00  10:08:00   3   4    19  63.2       0
# Dainius Zubrus    2013    17:33:00  14:58:00  19  20   188  64.4       1
# Mats Zuccarello   2013    17:08:00  13:47:00  44  38   294  57.8       7
# Jason Zucker      2013    12:59:00  12:02:00   9   9    68  58.8       1
#
#                          SOT_Scored SOT_Saved SOT_Pct
# Player            Season
# Spencer Abbott    2013            0         0     0.0
# Justin Abdelkader 2013            0         0     0.0
# Will Acton        2013            0         0     0.0
# Luke Adam         2013            0         1     0.0
# Craig Adams       2013            0         0     0.0
# ...                             ...       ...     ...
# Marek Zidlicky    2013            0         1     0.0
# Harry Zolnierczyk 2013            0         0     0.0
# Dainius Zubrus    2013            0         1     0.0
# Mats Zuccarello   2013            3         4    42.9
# Jason Zucker      2013            1         0   100.0
#
# [1005 rows x 49 columns]

# %%
skaters1314.columns
# Out:
# Index(['Age_x', 'Tm', 'Pos_x', 'GP_x', 'G', 'A', 'PTS', '+/-', 'PIM', 'PS',
#        'EV', 'PP', 'SH', 'GW', 'EV', 'PP', 'SH', 'S', 'S%', 'TOI', 'ATOI',
#        'BLK', 'HIT', 'FOW', 'FOL', 'FO%', 'CF', 'CA', 'CF%', 'CF% rel', 'FF',
#        'FA', 'FF%', 'FF% rel', 'oiSH%', 'oiSV%', 'PDO', 'oZS%', 'dZS%',
#        'TOI/60', 'TOI(EV)', 'TK', 'GV', 'SAtt.', 'Thru%', 'SOT_Att',
#        'SOT_Scored', 'SOT_Saved', 'SOT_Pct'],
#       dtype='object')

# %%
skaters2021.columns
# Out:
# Index(['Age_x', 'Tm', 'Pos_x', 'GP_x', 'G', 'A', 'PTS', '+/-', 'PIM', 'PS',
#        'EV', 'PP', 'SH', 'GW', 'EV', 'PP', 'SH', 'S', 'S%', 'TOI', 'ATOI',
#        'BLK', 'HIT', 'FOW', 'FOL', 'FO%', 'CF', 'CA', 'CF%', 'CF% rel', 'FF',
#        'FA', 'FF%', 'FF% rel', 'oiSH%', 'oiSV%', 'PDO', 'oZS%', 'dZS%',
#        'TOI/60', 'TOI(EV)', 'TK', 'GV', 'E+/-', 'SAtt.', 'Thru%', 'SOT_Att',
#        'SOT_Scored', 'SOT_Saved', 'SOT_Pct'],
#       dtype='object')

# %%
#save

skaters1314.to_csv('./Clean/skaters2013.csv')

# %% [markdown]
# #                       2014-2015 PLAYER STATS

# %%
#load
s1415=pd.DataFrame()
s1415= pd.read_excel('./Stats/2014-15/2014-15skaters.xlsx', engine= 'openpyxl')

sa_1415=pd.DataFrame()
sa_1415=pd.read_excel('./Stats/2014-15/2014-15skaters_adv.xlsx', engine='openpyxl')

ss_1415=pd.DataFrame()
ss_1415=pd.read_excel('./Stats/2014-15/2014-15skaters_misc.xlsx', engine='openpyxl')


#regular stats
s1415= preclean(s1415)
s1415['Season']=2014
s1415= s1415.set_index(['Player','Season'])


#advanced

sa_1415 = preclean(sa_1415)


sa_1415['Season']=2014
sa_1415= sa_1415.set_index(['Player','Season'])
sa_1415= sa_1415.drop(columns='Tm')



#shootout

ss_1415= shootout_cleaner(ss_1415)

ss_1415=ss_1415.reset_index()

ss_1415['Season']=2014

ss_1415=ss_1415.set_index(['Player','Season'])

ss_1415= ss_1415.drop(columns=['index'])

ss_1415= ss_1415.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})


#merge

skaters1415= s1415.merge(sa_1415, how='inner', on=['Player','Season']).merge(ss_1415, how='left', on=['Player','Season'])


#clean some more

skaters1415= skaters1415[skaters1415.index.get_level_values('Player') != 'Player']


replace_nulls= skaters1415[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters1415[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters1415= skaters1415.drop(columns=['Age_y','Pos_y','GP_y','E+/-'])

skaters1415
# Out:
# 0                        Age_x   Tm Pos_x GP_x   G   A PTS +/- PIM   PS  ...  \
# Player            Season                                                 ...
# Justin Abdelkader 2014      27  DET    LW   71  23  21  44   3  72  5.6  ...
# Will Acton        2014      27  EDM     C    3   0   0   0  -2   5 -0.1  ...
# Luke Adam         2014      24  CBJ     C    3   0   0   0   0   4    0  ...
# Craig Adams       2014      37  PIT    RW   70   1   6   7  -1  44 -0.3  ...
# Andrew Agozzino   2014      24  COL    LW    1   0   1   1   1   0  0.1  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ..  ..  ...  ...
# Marek Zidlicky    2014      37  DET     D   21   3   8  11  -2  14  1.7  ...
# Harry Zolnierczyk 2014      27  NYI    LW    2   0   0   0  -1   0 -0.1  ...
# Dainius Zubrus    2014      36  NJD     C   74   4   6  10  -9  42 -0.4  ...
# Mats Zuccarello   2014      27  NYR    LW   78  15  34  49  17  45  5.6  ...
# Jason Zucker      2014      23  MIN    LW   51  21   5  26  -9  18  3.7  ...
#
# 0                           TOI/60   TOI(EV)  TK  GV SAtt. Thru% SOT_Att  \
# Player            Season
# Justin Abdelkader 2014    17:55:00  14:10:00  16  29   237    65       0
# Will Acton        2014    10:43:00  09:21:00   2   0     3  66.7       0
# Luke Adam         2014    06:27:00  06:21:00   0   0     1     0       0
# Craig Adams       2014    09:45:00  07:10:00   6   7    76  67.1       0
# Andrew Agozzino   2014    09:45:00  09:45:00   1   0     2    50       0
# ...                            ...       ...  ..  ..   ...   ...     ...
# Marek Zidlicky    2014    20:56:00  18:06:00  20  44   289    45       0
# Harry Zolnierczyk 2014    11:08:00  10:23:00   1   0     3  33.3       0
# Dainius Zubrus    2014    14:40:00  12:58:00  19  19   107  68.2       0
# Mats Zuccarello   2014    17:16:00  14:54:00  60  41   286  53.8       6
# Jason Zucker      2014    15:04:00  12:57:00  21  19   193  64.2       0
#
# 0                        SOT_Scored SOT_Saved SOT_Pct
# Player            Season
# Justin Abdelkader 2014            0         0     0.0
# Will Acton        2014            0         0     0.0
# Luke Adam         2014            0         0     0.0
# Craig Adams       2014            0         0     0.0
# Andrew Agozzino   2014            0         0     0.0
# ...                             ...       ...     ...
# Marek Zidlicky    2014            0         0     0.0
# Harry Zolnierczyk 2014            0         0     0.0
# Dainius Zubrus    2014            0         0     0.0
# Mats Zuccarello   2014            3         3    50.0
# Jason Zucker      2014            0         0     0.0
#
# [1045 rows x 49 columns]

# %%
#save

skaters1415.to_csv('./Clean/skaters2014.csv')

# %% [markdown]
# #                          2015-2016 PLAYER STATS

# %%
#load
s1516=pd.DataFrame()
s1516= pd.read_excel('./Stats/2015-16/2015-16skaters.xlsx', engine= 'openpyxl')

sa_1516=pd.DataFrame()
sa_1516=pd.read_excel('./Stats/2015-16/2015-16skaters_adv.xlsx', engine='openpyxl')

ss_1516=pd.DataFrame()
ss_1516=pd.read_excel('./Stats/2015-16/2015-16skaters_misc.xlsx', engine='openpyxl')


#regular stats
s1516= preclean(s1516)
s1516['Season']=2015
s1516= s1516.set_index(['Player','Season'])


#advanced

sa_1516 = preclean(sa_1516)


sa_1516['Season']=2015
sa_1516= sa_1516.set_index(['Player','Season'])
sa_1516= sa_1516.drop(columns='Tm')



#shootout

ss_1516= shootout_cleaner(ss_1516)

ss_1516=ss_1516.reset_index()

ss_1516['Season']=2015

ss_1516=ss_1516.set_index(['Player','Season'])

ss_1516= ss_1516.drop(columns=['index'])

ss_1516= ss_1516.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})


#merge

skaters1516= s1516.merge(sa_1516, how='inner', on=['Player','Season']).merge(ss_1516, how='left', on=['Player','Season'])


#clean some more

skaters1516= skaters1516[skaters1516.index.get_level_values('Player') != 'Player']


replace_nulls= skaters1516[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters1516[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters1516= skaters1516.drop(columns=['Age_y','Pos_y','GP_y','E+/-'])

skaters1516
# Out:
# 0                        Age_x   Tm Pos_x GP_x   G   A PTS  +/-  PIM   PS  \
# Player            Season
# Justin Abdelkader 2015      28  DET    LW   82  19  23  42  -16  120  3.8
# Noel Acciari      2015      24  BOS     C   19   0   1   1   -4    8 -0.4
# Kenny Agostino    2015      23  CGY    LW    2   0   0   0   -2    0 -0.1
# Andrew Agozzino   2015      25  COL    LW    9   0   2   2   -1    0  0.1
# Karl Alzner       2015      27  WSH     D   82   4  17  21   14   26  5.4
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ...  ...
# Marek Zidlicky    2015      38  NYI     D   53   4  12  16    5   20  3.4
# Harry Zolnierczyk 2015      28  ANA    LW    1   0   0   0   -1    0 -0.1
# Dainius Zubrus    2015      37  SJS     C   50   3   4   7    4   20  0.4
# Mats Zuccarello   2015      28  NYR    RW   81  26  35  61    2   34  7.2
# Jason Zucker      2015      24  MIN    LW   71  13  10  23   -4   20  2.1
#
# 0                         ...    TOI/60   TOI(EV)  TK  GV SAtt. Thru% SOT_Att  \
# Player            Season  ...
# Justin Abdelkader 2015    ...  18:26:00  13:53:00  23  29   239  64.9       0
# Noel Acciari      2015    ...  09:54:00  08:31:00   1   4    28  64.3       0
# Kenny Agostino    2015    ...  13:33:00  12:12:00   2   5     3   100       0
# Andrew Agozzino   2015    ...  08:34:00  08:19:00   0   1    11  27.3       0
# Karl Alzner       2015    ...  21:23:00  18:28:00  24  41   185  40.5       0
# ...                       ...       ...       ...  ..  ..   ...   ...     ...
# Marek Zidlicky    2015    ...  15:35:00  13:39:00   5  21    93  51.6       0
# Harry Zolnierczyk 2015    ...  08:48:00  08:48:00   0   0     1   100       0
# Dainius Zubrus    2015    ...  11:35:00  10:33:00  15  15    65  49.2       0
# Mats Zuccarello   2015    ...  18:29:00  15:38:00  59  43   321  51.7       5
# Jason Zucker      2015    ...  15:36:00  13:54:00  40  27   279  56.3       0
#
# 0                        SOT_Scored SOT_Saved SOT_Pct
# Player            Season
# Justin Abdelkader 2015            0         0     0.0
# Noel Acciari      2015            0         0     0.0
# Kenny Agostino    2015            0         0     0.0
# Andrew Agozzino   2015            0         0     0.0
# Karl Alzner       2015            0         0     0.0
# ...                             ...       ...     ...
# Marek Zidlicky    2015            0         0     0.0
# Harry Zolnierczyk 2015            0         0     0.0
# Dainius Zubrus    2015            0         0     0.0
# Mats Zuccarello   2015            3         2    60.0
# Jason Zucker      2015            0         0     0.0
#
# [1093 rows x 49 columns]

# %%
#save

skaters1516.to_csv('./Clean/skaters2015.csv')

# %% [markdown]
# #                       2016-2017 PLAYER STATS

# %%
#load
s1617=pd.DataFrame()
s1617= pd.read_excel('./Stats/2016-17/2016-17skaters.xlsx', engine= 'openpyxl')

sa_1617=pd.DataFrame()
sa_1617=pd.read_excel('./Stats/2016-17/2016-17skaters_adv.xlsx', engine='openpyxl')

ss_1617=pd.DataFrame()
ss_1617=pd.read_excel('./Stats/2016-17/2016-17skaters_misc.xlsx', engine='openpyxl')


#regular stats
s1617= preclean(s1617)
s1617['Season']=2016
s1617= s1617.set_index(['Player','Season'])


#advanced

sa_1617 = preclean(sa_1617)


sa_1617['Season']=2016
sa_1617= sa_1617.set_index(['Player','Season'])
sa_1617= sa_1617.drop(columns='Tm')



#shootout

ss_1617= shootout_cleaner(ss_1617)

ss_1617=ss_1617.reset_index()

ss_1617['Season']=2016

ss_1617=ss_1617.set_index(['Player','Season'])

ss_1617= ss_1617.drop(columns=['index'])

ss_1617= ss_1617.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})


#merge

skaters1617= s1617.merge(sa_1617, how='inner', on=['Player','Season']).merge(ss_1617, how='left', on=['Player','Season'])


#clean some more

skaters1617= skaters1617[skaters1617.index.get_level_values('Player') != 'Player']


replace_nulls= skaters1617[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters1617[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters1617= skaters1617.drop(columns=['Age_y','Pos_y','GP_y','E+/-'])

skaters1617
# Out:
# 0                        Age_x   Tm Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Player            Season                                                  ...
# Spencer Abbott    2016      28  CHI    LW    1   0   0   0    0   0    0  ...
# Justin Abdelkader 2016      29  DET    LW   64   7  14  21  -20  50  0.7  ...
# Pontus Aberg      2016      23  NSH    LW   15   1   1   2   -2   4 -0.1  ...
# Noel Acciari      2016      25  BOS     C   29   2   3   5    3  16  0.5  ...
# Kenny Agostino    2016      24  STL    LW    7   1   2   3    0   2  0.3  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
# Mika Zibanejad    2016      23  NYR     C   56  14  23  37    9  16  4.2  ...
# Harry Zolnierczyk 2016      29  NSH    LW   24   2   2   4   -2  10  0.2  ...
# Mats Zuccarello   2016      29  NYR    RW   80  15  44  59   15  26    6  ...
# Jason Zucker      2016      25  MIN    LW   79  22  25  47   34  30  6.7  ...
# Valentin Zykov    2016      21  CAR    LW    2   1   0   1    1   0  0.2  ...
#
# 0                           TOI/60   TOI(EV)  TK  GV SAtt. Thru% SOT_Att  \
# Player            Season
# Spencer Abbott    2016    08:34:00  08:34:00   1   0     2    50       0
# Justin Abdelkader 2016    16:39:00  13:07:00  15  18   160    65       1
# Pontus Aberg      2016    12:20:00  12:05:00   5   2    24    50       0
# Noel Acciari      2016    10:14:00  10:01:00  10   4    43  55.8       0
# Kenny Agostino    2016    12:47:00  11:30:00   1   4    26  65.4       0
# ...                            ...       ...  ..  ..   ...   ...     ...
# Mika Zibanejad    2016    17:04:00  13:55:00  36  31   225  52.4       7
# Harry Zolnierczyk 2016    08:52:00  08:47:00   7   1    32  59.4       0
# Mats Zuccarello   2016    18:50:00  15:35:00  70  54   327  57.8       7
# Jason Zucker      2016    15:17:00  14:22:00  44  23   292  58.9       1
# Valentin Zykov    2016    06:15:00  05:09:00   0   1     4    75       0
#
# 0                        SOT_Scored SOT_Saved SOT_Pct
# Player            Season
# Spencer Abbott    2016            0         0     0.0
# Justin Abdelkader 2016            1         0   100.0
# Pontus Aberg      2016            0         0     0.0
# Noel Acciari      2016            0         0     0.0
# Kenny Agostino    2016            0         0     0.0
# ...                             ...       ...     ...
# Mika Zibanejad    2016            3         4    42.9
# Harry Zolnierczyk 2016            0         0     0.0
# Mats Zuccarello   2016            4         3    57.1
# Jason Zucker      2016            0         1     0.0
# Valentin Zykov    2016            0         0     0.0
#
# [1043 rows x 49 columns]

# %%
#save

skaters1617.to_csv('./Clean/skaters2016.csv')

# %% [markdown]
# #                              2017-2018 PLAYER STATS

# %%
#load
s1718=pd.DataFrame()
s1718= pd.read_excel('./Stats/2017-18/2017-18skaters.xlsx', engine= 'openpyxl')

sa_1718=pd.DataFrame()
sa_1718=pd.read_excel('./Stats/2017-18/2017-18skaters_misc.xlsx', engine='openpyxl')

ss_1718=pd.DataFrame()
ss_1718=pd.read_excel('./Stats/2017-18/2017-18skaters_shootout.xlsx', engine='openpyxl')


#regular stats
s1718= preclean(s1718)
s1718['Season']=2017
s1718= s1718.set_index(['Player','Season'])


#advanced

sa_1718 = preclean(sa_1718)


sa_1718['Season']=2017
sa_1718= sa_1718.set_index(['Player','Season'])
sa_1718= sa_1718.drop(columns='Tm')



#shootout

ss_1718=ss_1718.reset_index()

ss_1718['Season']=2017

ss_1718=ss_1718.set_index(['Player','Season'])

ss_1718= ss_1718.drop(columns=['Tm','index'])

ss_1718= ss_1718.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})


#merge

skaters1718= s1718.merge(sa_1718, how='inner', on=['Player','Season']).merge(ss_1718, how='left', on=['Player','Season'])


#clean some more

skaters1718= skaters1718[skaters1718.index.get_level_values('Player') != 'Player']


replace_nulls= skaters1718[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters1718[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters1718= skaters1718.drop(columns=['Age_y','Pos_y','GP_y','E+/-'])

skaters1718
# Out:
#                          Age_x   Tm Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Player            Season                                                  ...
# Justin Abdelkader 2017      30  DET    LW   75  13  22  35  -11  78  2.5  ...
# Pontus Aberg      2017      24  TOT    LW   53   4  12  16    9  10  1.3  ...
#                   2017      24  NSH    LW   37   2   6   8    8   8  0.6  ...
#                   2017      24  EDM    LW   16   2   6   8    1   2  0.7  ...
# Noel Acciari      2017      26  BOS     C   60  10   1  11   -6   9  0.6  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
# Henrik Zetterberg 2017      37  DET    LW   82  11  45  56    1  14  4.4  ...
# Mika Zibanejad    2017      24  NYR     C   72  27  20  47  -23  14  4.7  ...
# Mats Zuccarello   2017      30  NYR    LW   80  16  37  53  -10  36  4.4  ...
# Jason Zucker      2017      26  MIN    LW   82  33  31  64    8  44  7.8  ...
# Valentin Zykov    2017      22  CAR    LW   10   3   4   7    4   2    1  ...
#
#                             TOI/60   TOI(EV)  TK  GV SAtt. Thru% SOT_Att  \
# Player            Season
# Justin Abdelkader 2017    16:33:00  12:49:00  21  34   200  54.5     1.0
# Pontus Aberg      2017    12:10:00  11:48:00  12  20   125    56     0.0
#                   2017    12:10:00  11:48:00  12  20   125    56     0.0
#                   2017    12:10:00  11:48:00  12  20   125    56     0.0
# Noel Acciari      2017    12:55:00  11:24:00  20   9   113  58.4     0.0
# ...                            ...       ...  ..  ..   ...   ...     ...
# Henrik Zetterberg 2017    19:30:00  16:51:00  51  57   332  54.2     3.0
# Mika Zibanejad    2017    17:58:00  13:49:00  49  63   367  57.8     7.0
# Mats Zuccarello   2017    18:55:00  15:03:00  69  58   291  61.2     7.0
# Jason Zucker      2017    16:58:00  14:11:00  54  37   338  65.7     1.0
# Valentin Zykov    2017    13:42:00  12:45:00   5   4    28  64.3     0.0
#
#                          SOT_Scored SOT_Saved SOT_Pct
# Player            Season
# Justin Abdelkader 2017          1.0       0.0   100.0
# Pontus Aberg      2017          0.0       0.0     0.0
#                   2017          0.0       0.0     0.0
#                   2017          0.0       0.0     0.0
# Noel Acciari      2017          0.0       0.0     0.0
# ...                             ...       ...     ...
# Henrik Zetterberg 2017          0.0       3.0     0.0
# Mika Zibanejad    2017          3.0       4.0    42.9
# Mats Zuccarello   2017          4.0       3.0    57.1
# Jason Zucker      2017          0.0       1.0     0.0
# Valentin Zykov    2017          0.0       0.0     0.0
#
# [1037 rows x 49 columns]

# %%
#save

skaters1718.to_csv('./Clean/skaters2017.csv')

# %% [markdown]
# #                             2018-2019 PLAYER STATS

# %%
#load
s1819=pd.DataFrame()
s1819= pd.read_excel('./Stats/2018-19/2018-19skaters.xlsx', engine= 'openpyxl')

sa_1819=pd.DataFrame()
sa_1819=pd.read_excel('./Stats/2018-19/2018-19skaters_adv.xlsx', engine='openpyxl')

ss_1819=pd.DataFrame()
ss_1819=pd.read_excel('./Stats/2018-19/2018-19skaters_shootout.xlsx', engine='openpyxl')


#regular stats
s1819= preclean(s1819)
s1819['Season']=2018
s1819= s1819.set_index(['Player','Season'])


#advanced

sa_1819 = preclean(sa_1819)


sa_1819['Season']=2018
sa_1819= sa_1819.set_index(['Player','Season'])
sa_1819= sa_1819.drop(columns='Tm')



#shootout

ss_1819=ss_1819.reset_index()

ss_1819['Season']=2018

ss_1819=ss_1819.set_index(['Player','Season'])

ss_1819= ss_1819.drop(columns=['Tm','index'])

ss_1819= ss_1819.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})


#merge

skaters1819= s1819.merge(sa_1819, how='inner', on=['Player','Season']).merge(ss_1819, how='left', on=['Player','Season'])


#clean some more

skaters1819= skaters1819[skaters1819.index.get_level_values('Player') != 'Player']


replace_nulls= skaters1819[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters1819[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters1819= skaters1819.drop(columns=['Age_y','Pos_y','GP_y','E+/-'])

skaters1819
# Out:
#                          Age_x   Tm Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Player            Season                                                  ...
# Justin Abdelkader 2018      31  DET    LW   71   6  13  19  -14  38  0.1  ...
# Pontus Aberg      2018      25  TOT    LW   59  12  13  25  -14  20    2  ...
#                   2018      25  ANA    LW   37  11   8  19  -10  14  1.8  ...
#                   2018      25  MIN    LW   22   1   5   6   -4   6  0.2  ...
# Vitaly Abramov    2018      20  OTT    RW    1   0   0   0   -3   0 -0.1  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
# Jason Zucker      2018      27  MIN    LW   81  21  21  42   -9  28  4.1  ...
# Valentin Zykov    2018      23  TOT    LW   28   2   3   5   -5   2  0.1  ...
#                   2018      23  CAR    LW   13   0   3   3   -1   0  0.1  ...
#                   2018      23  VEG    LW   10   2   0   2   -3   0  0.1  ...
#                   2018      23  EDM    LW    5   0   0   0   -1   2 -0.1  ...
#
#                             TOI/60   TOI(EV)  TK  GV SAtt. Thru% SOT_Att  \
# Player            Season
# Justin Abdelkader 2018    15:23:00  12:54:00   9  40   159  59.7     2.0
# Pontus Aberg      2018    14:36:00  12:31:00  15  36   211  47.9     4.0
#                   2018    14:36:00  12:31:00  15  36   211  47.9     4.0
#                   2018    14:36:00  12:31:00  15  36   211  47.9     4.0
# Vitaly Abramov    2018    13:52:00  13:01:00   4   2     5     0     0.0
# ...                            ...       ...  ..  ..   ...   ...     ...
# Jason Zucker      2018    17:05:00  14:31:00  47  31   398  53.8     4.0
# Valentin Zykov    2018    09:57:00  08:23:00   9  15    57  50.9     0.0
#                   2018    09:57:00  08:23:00   9  15    57  50.9     0.0
#                   2018    09:57:00  08:23:00   9  15    57  50.9     0.0
#                   2018    09:57:00  08:23:00   9  15    57  50.9     0.0
#
#                          SOT_Scored SOT_Saved SOT_Pct
# Player            Season
# Justin Abdelkader 2018          0.0       2.0     0.0
# Pontus Aberg      2018          1.0       3.0    25.0
#                   2018          1.0       3.0    25.0
#                   2018          1.0       3.0    25.0
# Vitaly Abramov    2018          0.0       0.0     0.0
# ...                             ...       ...     ...
# Jason Zucker      2018          1.0       3.0    25.0
# Valentin Zykov    2018          0.0       0.0     0.0
#                   2018          0.0       0.0     0.0
#                   2018          0.0       0.0     0.0
#                   2018          0.0       0.0     0.0
#
# [1076 rows x 49 columns]

# %%
primary index player
secondary index year

# %%
skaters1819[skaters1819['Tm'] == "TOT"]
# Out:
#                         Age_x   Tm Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Season Player                                                            ...
# 2018   Pontus Aberg        25  TOT    LW   59  12  13  25  -14  20    2  ...
#        Kenny Agostino      26  TOT    LW   63   6  18  24   -3  34  1.6  ...
#        Darren Archibald    28  TOT    RW   12   1   1   2   -3  12  0.1  ...
#        Nathan Beaulieu     26  TOT     D   48   3   9  12    6  39  2.7  ...
#        Anthony Bitetto     28  TOT     D   36   0   3   3   -7  12  0.3  ...
# ...                       ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
#        Jordan Weal         26  TOT     C   63   8  13  21   -8  18  1.2  ...
#        Dale Weise          30  TOT    RW   51   5   6  11   -8  19  0.2  ...
#        Chris Wideman       29  TOT     D   25   2   5   7  -12  18  0.3  ...
#        Mats Zuccarello     31  TOT    LW   48  12  28  40   -8  24  3.4  ...
#        Valentin Zykov      23  TOT    LW   28   2   3   5   -5   2  0.1  ...
#
#                           TOI(EV)  TK  GV E+/- SAtt. Thru% SOT_Att SOT_Scored  \
# Season Player
# 2018   Pontus Aberg      12:31:00  15  36 -0.8   211  47.9     4.0        1.0
#        Kenny Agostino    11:36:00  25  30 -0.9   144  54.9     1.0        0.0
#        Darren Archibald  07:22:00   1   3   -1    11  90.9     0.0        0.0
#        Nathan Beaulieu   14:40:00   9  22 -2.7   106  56.6     0.0        0.0
#        Anthony Bitetto   11:43:00   6  13 -7.7    70  42.9     0.0        0.0
# ...                           ...  ..  ..  ...   ...   ...     ...        ...
#        Jordan Weal       12:19:00  20  19  9.2   137  54.7     2.0        1.0
#        Dale Weise        10:19:00   9  10  1.3    94  61.7     0.0        0.0
#        Chris Wideman     10:53:00   3   9 -2.4    66  40.9     0.0        0.0
#        Mats Zuccarello   15:20:00  38  29  0.9   182  57.1     5.0        2.0
#        Valentin Zykov    08:23:00   9  15  0.7    57  50.9     0.0        0.0
#
#                         SOT_Saved SOT_Pct
# Season Player
# 2018   Pontus Aberg           3.0    25.0
#        Kenny Agostino         1.0     0.0
#        Darren Archibald       0.0     0.0
#        Nathan Beaulieu        0.0     0.0
#        Anthony Bitetto        0.0     0.0
# ...                           ...     ...
#        Jordan Weal            1.0    50.0
#        Dale Weise             0.0     0.0
#        Chris Wideman          0.0     0.0
#        Mats Zuccarello        3.0    40.0
#        Valentin Zykov         0.0     0.0
#
# [81 rows x 50 columns]

# %%
#save

skaters1819.to_csv('./Clean/skaters2018.csv')

# %% [markdown]
# #                    2019-2020 PLAYER STATS

# %%
#load
s1920=pd.DataFrame()
s1920= pd.read_excel('./Stats/2019-20/2019-20skaters.xlsx', engine= 'openpyxl')

sa_1920=pd.DataFrame()
sa_1920=pd.read_excel('./Stats/2019-20/2019-20skaters_adv.xlsx', engine='openpyxl')

ss_1920=pd.DataFrame()
ss_1920=pd.read_excel('./Stats/2019-20/2019-20skaters_shootout.xlsx', engine='openpyxl')


#regular stats
s1920= preclean(s1920)
s1920['Season']=2019
s1920= s1920.set_index(['Player','Season'])


#advanced

sa_1920 = preclean(sa_1920)


sa_1920['Season']=2019
sa_1920= sa_1920.set_index(['Player','Season'])
sa_1920= sa_1920.drop(columns='Tm')



#shootout

ss_1920=ss_1920.reset_index()

ss_1920['Season']=2019

ss_1920=ss_1920.set_index(['Player','Season'])

ss_1920= ss_1920.drop(columns=['Tm','index'])

ss_1920= ss_1920.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})


#merge

skaters1920= s1920.merge(sa_1920, how='inner', on=['Player','Season']).merge(ss_1920, how='left', on=['Player','Season'])


#clean some more

skaters1920= skaters1920[skaters1920.index.get_level_values('Player') != 'Player']


replace_nulls= skaters1920[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters1920[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters1920= skaters1920.drop(columns=['Age_y','Pos_y','GP_y','E+/-'])

skaters1920
# Out:
#                          Age_x   Tm Pos_x GP_x   G   A PTS  +/- PIM   PS  ...  \
# Player            Season                                                  ...
# Justin Abdelkader 2019      32  DET    LW   49   0   3   3  -14  25 -0.9  ...
# Pontus Aberg      2019      26  TOR    LW    5   0   1   1    0   0    0  ...
# Vitaly Abramov    2019      21  OTT    RW    2   1   0   1    0   2  0.2  ...
# Noel Acciari      2019      28  FLA     C   66  20   7  27    2  21  2.9  ...
# Andrew Agozzino   2019      29  TOT    LW   22   1   2   3    3   4  0.3  ...
# ...                        ...  ...   ...  ...  ..  ..  ..  ...  ..  ...  ...
# Mats Zuccarello   2019      32  MIN    LW   65  15  22  37   -9  18  3.1  ...
# Jason Zucker      2019      28  TOT    LW   60  20  21  41   -4  21  4.3  ...
#                   2019      28  MIN    LW   45  14  15  29   -3  19    3  ...
#                   2019      28  PIT    LW   15   6   6  12   -1   2  1.3  ...
# Valentin Zykov    2019      24  VEG    LW   15   1   3   4   -2   6  0.1  ...
#
#                             TOI/60   TOI(EV)  TK  GV SAtt. Thru% SOT_Att  \
# Player            Season
# Justin Abdelkader 2019    11:32:00  09:48:00  10  18    76  52.6     0.0
# Pontus Aberg      2019    08:42:00  08:42:00   1   2     5    80     0.0
# Vitaly Abramov    2019    05:47:00  05:47:00   0   1     4    75     0.0
# Noel Acciari      2019    15:57:00  13:08:00  32  21   189  57.1     0.0
# Andrew Agozzino   2019    07:21:00  06:49:00   5   4    18  55.6     0.0
# ...                            ...       ...  ..  ..   ...   ...     ...
# Mats Zuccarello   2019    15:56:00  13:16:00  33  17   164  58.5     3.0
# Jason Zucker      2019    16:19:00  13:45:00  31  25   173  64.2     0.0
#                   2019    16:19:00  13:45:00  31  25   173  64.2     0.0
#                   2019    16:19:00  13:45:00  31  25   173  64.2     0.0
# Valentin Zykov    2019    12:13:00  10:50:00   5  12    31  61.3     0.0
#
#                          SOT_Scored SOT_Saved SOT_Pct
# Player            Season
# Justin Abdelkader 2019          0.0       0.0     0.0
# Pontus Aberg      2019          0.0       0.0     0.0
# Vitaly Abramov    2019          0.0       0.0     0.0
# Noel Acciari      2019          0.0       0.0     0.0
# Andrew Agozzino   2019          0.0       0.0     0.0
# ...                             ...       ...     ...
# Mats Zuccarello   2019          1.0       2.0    33.3
# Jason Zucker      2019          0.0       0.0     0.0
#                   2019          0.0       0.0     0.0
#                   2019          0.0       0.0     0.0
# Valentin Zykov    2019          0.0       0.0     0.0
#
# [1016 rows x 49 columns]

# %%
skaters1920.columns
# Out:
# Index(['Age_x', 'Tm', 'Pos_x', 'GP_x', 'G', 'A', 'PTS', '+/-', 'PIM', 'PS',
#        'EV', 'PP', 'SH', 'GW', 'EV', 'PP', 'SH', 'S', 'S%', 'TOI', 'ATOI',
#        'BLK', 'HIT', 'FOW', 'FOL', 'FO%', 'CF', 'CA', 'CF%', 'CF% rel', 'FF',
#        'FA', 'FF%', 'FF% rel', 'oiSH%', 'oiSV%', 'PDO', 'oZS%', 'dZS%',
#        'TOI/60', 'TOI(EV)', 'TK', 'GV', 'E+/-', 'SAtt.', 'Thru%', 'SOT_Att',
#        'SOT_Scored', 'SOT_Saved', 'SOT_Pct'],
#       dtype='object')

# %%
#save

skaters1920.to_csv('./Clean/skaters2019.csv')

# %% [markdown]
# #                         2020-2021 PLAYER STATS

# %%
#load
s2021=pd.DataFrame()
s2021= pd.read_excel('./Stats/2020-21/2020-21skaters.xlsx', engine= 'openpyxl')

sa_2021=pd.DataFrame()
sa_2021=pd.read_excel('./Stats/2020-21/2020-21skaters_adv.xlsx', engine='openpyxl')

ss_2021=pd.DataFrame()
ss_2021=pd.read_excel('./Stats/2020-21/2020-21skaters_shootout.xlsx', engine='openpyxl')


#regular stats
s2021= preclean(s2021)
s2021['Season']=2020
s2021= s2021.set_index(['Player','Season'])


#advanced

sa_2021 = preclean(sa_2021)


sa_2021['Season']=2020
sa_2021= sa_2021.set_index(['Player','Season'])
sa_2021= sa_2021.drop(columns='Tm')



#shootout

ss_2021=ss_2021.reset_index()

ss_2021['Season']=2020

ss_2021=ss_2021.set_index(['Player','Season'])

ss_2021= ss_2021.drop(columns=['Tm','index'])

ss_2021= ss_2021.rename(columns={'Att.':'SOT_Att','Made':'SOT_Scored','Miss':'SOT_Saved','Pct.':'SOT_Pct'})


#merge

skaters2021= s2021.merge(sa_2021, how='inner', on=['Player','Season']).merge(ss_2021, how='left', on=['Player','Season'])


#clean some more

skaters2021= skaters2021[skaters2021.index.get_level_values('Player') != 'Player']


replace_nulls= skaters2021[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']].fillna (value=0)


skaters2021[['SOT_Att','SOT_Scored','SOT_Saved','SOT_Pct']]= replace_nulls

skaters2021= skaters2021.drop(columns=['Age_y','Pos_y','GP_y','E+/-'])

skaters2021
# Out:
#                        Age_x   Tm Pos_x GP_x   G   A PTS +/- PIM   PS  ...  \
# Player          Season                                                 ...
# Vitaly Abramov  2020      22  OTT    RW    2   0   0   0   0   0    0  ...
# Noel Acciari    2020      29  FLA     C   41   4   7  11   0   9  0.4  ...
# Calen Addison   2020      20  MIN     D    3   0   0   0   0   0    0  ...
# Kenny Agostino  2020      28  TOR    LW    1   0   0   0   0   0    0  ...
# Andrew Agozzino 2020      30  ANA    LW    3   0   1   1   0   0  0.1  ...
# ...                      ...  ...   ...  ...  ..  ..  ..  ..  ..  ...  ...
# Mika Zibanejad  2020      27  NYR     C   56  24  26  50   2  18  5.7  ...
# Radim Zohorna   2020      24  PIT     F    8   2   2   4   4   4  0.6  ...
# Artem Zub       2020      25  OTT     D   47   3  11  14   4  26  2.8  ...
# Mats Zuccarello 2020      33  MIN    LW   42  11  24  35   9   8  3.9  ...
# Jason Zucker    2020      29  PIT    LW   38   9   9  18  -8  21  1.3  ...
#
#                           TOI/60   TOI(EV)  TK  GV SAtt. Thru% SOT_Att  \
# Player          Season
# Vitaly Abramov  2020    09:43:00  09:43:00   0   0     2     0     0.0
# Noel Acciari    2020    15:24:00  12:13:00  17  11   102  66.7     0.0
# Calen Addison   2020    18:31:00  15:46:00   0   0     6  66.7     0.0
# Kenny Agostino  2020    04:08:00  04:08:00   0   0     0   NaN     0.0
# Andrew Agozzino 2020    12:11:00  11:55:00   0   1     5    60     0.0
# ...                          ...       ...  ..  ..   ...   ...     ...
# Mika Zibanejad  2020    20:06:00  14:04:00  39  45   316  54.1     2.0
# Radim Zohorna   2020    09:02:00  08:05:00   3   0    11  72.7     0.0
# Artem Zub       2020    18:23:00  16:09:00   8  36    85  45.9     0.0
# Mats Zuccarello 2020    16:41:00  14:17:00  18  18   143  51.7     2.0
# Jason Zucker    2020    15:41:00  14:18:00  18  13   119  56.3     0.0
#
#                        SOT_Scored SOT_Saved SOT_Pct
# Player          Season
# Vitaly Abramov  2020          0.0       0.0     0.0
# Noel Acciari    2020          0.0       0.0     0.0
# Calen Addison   2020          0.0       0.0     0.0
# Kenny Agostino  2020          0.0       0.0     0.0
# Andrew Agozzino 2020          0.0       0.0     0.0
# ...                           ...       ...     ...
# Mika Zibanejad  2020          0.0       2.0     0.0
# Radim Zohorna   2020          0.0       0.0     0.0
# Artem Zub       2020          0.0       0.0     0.0
# Mats Zuccarello 2020          1.0       1.0    50.0
# Jason Zucker    2020          0.0       0.0     0.0
#
# [1032 rows x 49 columns]

# %%
skaters2021.columns
# Out:
# Index(['Age_x', 'Tm', 'Pos_x', 'GP_x', 'G', 'A', 'PTS', '+/-', 'PIM', 'PS',
#        'EV', 'PP', 'SH', 'GW', 'EV', 'PP', 'SH', 'S', 'S%', 'TOI', 'ATOI',
#        'BLK', 'HIT', 'FOW', 'FOL', 'FO%', 'CF', 'CA', 'CF%', 'CF% rel', 'FF',
#        'FA', 'FF%', 'FF% rel', 'oiSH%', 'oiSV%', 'PDO', 'oZS%', 'dZS%',
#        'TOI/60', 'TOI(EV)', 'TK', 'GV', 'E+/-', 'SAtt.', 'Thru%', 'SOT_Att',
#        'SOT_Scored', 'SOT_Saved', 'SOT_Pct'],
#       dtype='object')

# %%
#save

skaters2021.to_csv('./Clean/skaters2020.csv')
